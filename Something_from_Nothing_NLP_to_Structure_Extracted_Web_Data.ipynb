# %% [markdown]
# #Introduction
#
# In this guide, we will be creating a structured document database based on the [Institude for the Study of War](http://www.understandingwar.org/) (ISW) production library. ISW creates informational products for diplomatic and intelligence professionals to gain a deeper understanding of conflicts occurring around the world.
#
# This guide will be en exercise in web extraction and natural language processing (NLP), and named entity recognition (NER). For the NLP, we will primarily be using the open-source Python libraries NLTK and Spacy. This guide is not intended primarily to be demonstration of a use-case for web extraction and NLP, **not** a comprehensive beginner tutorial to the usage of either technique. If you are new to NLP or web extraction, I would urge you to follow a different guide or look through the [Spacy](https://spacy.io/api/doc), [BeautifulSoup](https://www.crummy.com/software/BeautifulSoup/bs4/doc/), and [NLTK](https://www.nltk.org/) documentation pages. However, I will attempt throughout this guide to explain concepts at the simplest level for those who have never been exposed to these concepts before. If, at the end of the guide, you are still confused and would like some further explanation, you will find mind my LinkedIn information below the article. Feel free to reach out to me with any questions or suggestions! Additionally, you can find all of the original code for this guide in the [Colaboratory Notebook](https://colab.research.google.com/drive/1pTrOXW3k5VQo1lEaahCo79AHpyp5ZdfQ?usp=sharing).
#
# ##Import Relevant Libraries

# %%
#Import libraries

import requests
import nltk
import math
import re
import spacy
import regex as re
import pandas as pd
import numpy as np
import statistics as stats
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import json

#You will need to download some packages from NLTK. 

from bs4 import BeautifulSoup 
from nltk import *
nltk.download('stopwords')
nltk.download('punkt')
from nltk.corpus import stopwords

#In most environments, you will need to install NER-D. 

# !pip install ner-d
from nerd import ner

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer
from sklearn.cluster import MiniBatchKMeans
from sklearn.feature_extraction.text import TfidfVectorizer
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Requirement already satisfied: ner-d in /usr/local/lib/python3.6/dist-packages (0.3.0)
# Requirement already satisfied: spacy==2.2.2 in /usr/local/lib/python3.6/dist-packages (from ner-d) (2.2.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (2.23.0)
# Requirement already satisfied: thinc<7.4.0,>=7.3.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (7.3.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.3.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (0.8.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (0.4.1)
# Requirement already satisfied: srsly<1.1.0,>=0.1.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (1.0.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (2.0.3)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (1.1.3)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (1.18.5)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (3.0.2)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (2.0.0)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (1.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy==2.2.2->ner-d) (50.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.2->ner-d) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.2->ner-d) (2020.6.20)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.2->ner-d) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy==2.2.2->ner-d) (3.0.4)
# Requirement already satisfied: tqdm<5.0.0,>=4.10.0 in /usr/local/lib/python3.6/dist-packages (from thinc<7.4.0,>=7.3.0->spacy==2.2.2->ner-d) (4.41.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->spacy==2.2.2->ner-d) (3.2.0)

# %% [markdown]
# ##Initializing Variables
#
# First, we will initialize the data fields we want in our final structured data. For each article, I want to extract the **title**, **date of publication**, **names of people**, **names of places**, and various other information. I'll also be enhancing the information that already exists in the article - for example, we'll use the place names we find in the article to get relevant coordinates, which could be useful for visualizing data later on. We'll also initialize some fields that will be filled in by **machine learning** models later, like topic modeling fields and extracted keywords.

# %%
#Initialize data fields for final dataset

dates=[]
titles=[]
locations=[]
people=[]
key_countries=[]
content_text=[]
links=[]
coord_list=[]
mentioned_countries=[]
keywords=[]
topic_categories=[]

#initializing clustering variables for later topic modeling

cluster_keywords=[]
cluster_number=[]

#Initialize the NLP object using the SPACY library
nlp = spacy.load("en_core_web_sm")

# %%
#Defining a list of all the countries in the world, for later referencing in extracted text

country_list=['Afghanistan','Albania','Algeria','Andorra','Angola','Antigua','Barbuda',
              'Argentina','Armenia','Australia','Austria','Azerbaijan','Bahamas','Bahrain',
              'Bangladesh','Barbados','Belarus','Belgium','Belize','Benin','Bhutan',
              'Bolivia','Bosnia','Herzegovina','Botswana','Brazil','Brunei','Bulgaria',
              'Burkina Faso','Burundi',"Cote d'lvoire",'Cabo Verde','Cambodia','Cameroon',
              'Canada','Central African Republic','Chad','Chile','China','Colombia','Comoros',
              'Congo','Costa Rica','Croatia','Cuba','Cyprus','Czechia','Czech Republic',
              'Democratic Republic of the Congo','Denmark','Djibouti','Dominica',
              'Domincan Republic','Ecuador','Egypt','El Salvador','Equatorial Guinea',
              'Eritrea','Estonia','Eswatini','Ethiopia','Fiji','Finland','France','Gabon',
              'Gambia','Georgia','Germany','Ghana','Greece','Grenada','Guatemala','Guinea',
              'Guinea-Bissau','Guyana','Haiti','Holy See','Honduras','Hungary','Iceland',
              'India','Indonesia','Iran','Iraq','Ireland','Israel','Italy','Jamaica','Japan',
              'Jordan','Kazakhstan','Kenya','Kiribati','Kuwait','Kyrgyzstan','Laos','Latvia',
              'Lebanon','Lesotho','Liberia','Libya','Liechtenstein','Lithuania','Luxembourg',
              'Madagascar','Malawi','Malaysia','Maldives','Mali','Malta','Marshall Islands',
              'Mauritania','Mauritius','Mexico','Micronesia','Moldova','Monaco','Mongolia',
              'Montenegro','Morocco','Mozambique','Myanmar','Burma','Namibia','Nauru','Nepal',
              'Netherlands','New Zealand','Nicaragua','Niger','Nigeria','North Korea',
              'North Macedonia','Norway','Oman','Pakistan','Palau','Palestine','Palestine State',
              'Panama','Papua New Guinea','Paraguay','Peru','Philippines','Poland','Portugal',
              'Qatar','Romania','Russia','Rwanda','Saint Kitts and Nevis','Saint Lucia',
              'Saint Vincent and the Grenadines','Samoa','San Morino','Sao Tome and Principe',
              'Saudi Arabia','Senegal','Serbia','Seychelles','Sierra Leone','Singapore',
              'Slovakia','Slovenia','Solomon Islands','Somalia','South Africa','South Korea',
              'South Sudan','Spain','Suriname','Sweden','Switzerland','Syria','Tajikistan',
              'Tanzania','Thailand','Timor-Leste','Togo','Tonga','Trinidad','Tobago','Tunisia',
              'Turkey','Turkmenistan','Tuvalu','Uganda','Ukraine','United Kingdom',
              'United States of America','Uruguay','Uzbekistan','Vanuatu','Venezuela',
              'Vietnam','Yemen','Zambia','Zimbabwe']

# %% [markdown]
# ##Extracting Hrefs
#
# We will be extracting our articles from the Institute for the Study of War's production library. First, we will scrape the **'browse'** page to get individual href links for each product. Then we store those links in a list for our extraction functions to visit later.

# %%
#Getting product links from ISW browse page

urls=['http://www.understandingwar.org/publications?page={}'.format(i) for i in range(179)]
hrefs=[]

def get_hrefs(page,class_name):
  page=requests.get(page)
  soup=BeautifulSoup(page.text,'html.parser')
  container=soup.find_all('div',{'class':class_name})
  container_a=container[0].find_all('a')
  links=[container_a[i].get('href') for i in range(len(container_a))]
  for link in links:
    if link[0]=='/':
      hrefs.append('http://www.understandingwar.org'+link)

for url in urls:
  get_hrefs(url,'view-content')

# %% [markdown]
# #Web Extraction
#
# The first few functions we'll write are fairly straightforward text extraction. This tutorial is not intended to be a tutorial on the usage of beautifulsoup - for an introduction to web scraping in Python, check out the beautifulsoup documentation [here](https://www.crummy.com/software/BeautifulSoup/bs4/doc/).
#
# For our first function, we will be extracting the publication date. It scans through the html document extracted from the product's webpage, and finds a field with the class of **'submitted'**. This contains our production date.
#
# Next, we want the product title. Again, this field is conveniently labeled with a class of **'title'**.
#
# Finally, we will extract the full text of the article. When I extract text, I often find that I follow an 'extract-first, filter-later' style of web extraction. That means that, in my initial text extraction, I perform minimal filtering and processing of the text. I prefer to conduct that processing later on in my analysis, as it becomes necessary. However, if you are more advanced, you may want to conduct more pre-processing of the extracted text than the below function demonstrates. Again, I recommend you follow the beautifulsoup [documentation](https://www.crummy.com/software/BeautifulSoup/bs4/doc/) for reference.
#
# For my *get_contents* function, I stuck to the bare bones - I listed a few html parents in a blacklist, for text that I don't want to be extracted. Then I extract all the text from the page and append it into a temporary string, which in turn is appended into the *list* **content_text**.

# %%
#Function to extract publication data
def get_date(soup):
  try:
    data=soup.find('span',{'class':'submitted'})
    content=data.find('span')
    date=content.get('content')
    dates.append(date)
  except Exception:
    dates.append('')
    pass

#Function to extract product title
def get_title(soup):
  try:
    title=soup.find('h1',{'class':'title'}).contents
    titles.append(title[0])
  except Exception:
    titles.append('')
    pass

#Function to extract product's text contents
def get_contents(soup):
  try:
    parents_blacklist=['[document]','html','head',
                       'style','script','body',
                       'div','a','section','tr',
                       'td','label','ul','header',
                       'aside',]
    content=''
    text=soup.find_all(text=True)
  
    for t in text:
      if t.parent.name not in parents_blacklist and len(t) > 10:
        content=content+t+' '

    content_text.append(content)
  except Exception:
    content_text.append('')
    pass

# %% [markdown]
# #Natural Language Porcessing
#
# Next, we will figure out what countries are referenced in the product. There are many APIs that could be used in checking text content for countries, but here we will use a simple fool-proof method: a humble *list* of all the countries in the world. This list is derived from [Wikipedia](https://en.wikipedia.org/wiki/Lists_of_countries_and_territories), so there may be more comprehensive options. This works fine for demonstration purposes, but I urge you to explore more advanced and elegant options!
#
# After the function identified **all_mentioned_countries** in the article, it uses basic statistical analysis to identify which countries are featured most prominently - these countries are most likely to be the point of focus for the article's narrative. To do this, the function counts the number of times a country is mentioned throughout the article and then finds countries mentioned more times than the average. These countries are then appended to a **key_countries** *list*.

# %%
#Reference a list of all countries against the body of the text. 
#If a word in the text matches a country in the list, it is then added to a list of countries. 

def get_countries(content_list):
  iteration=1
  for i in range(len(content_list)):
    print('Getting countries',iteration,'/',len(content_list))
    temp_list=[]
    for word in word_tokenize(content_list[i]):
      for country in country_list:
        if word.lower().strip() == country.lower().strip():
          temp_list.append(country)

    counted_countries=dict(Counter(temp_list))
    temp_dict=dict.fromkeys(temp_list,0)
    temp_list=list(temp_dict)
    if len(temp_list)==0:
      temp_list.append('Worldwide')
    mentioned_countries.append(temp_list)

    #Counting the number of mentions for each country, then checking each count against the mean. 
    #If a country is mentioned more than the mean number of mentions, it is noted as a keyword. 

    keywords=[]
    for key in counted_countries.keys():
      if counted_countries[key] > np.mean(list(counted_countries.values())):
        keywords.append(key)
    if len(keywords) != 0:
      key_countries.append(keywords)
    else:
      key_countries.append(temp_list)
    iteration+=1

# %% [markdown]
# ##Named Entity Recognition: Places
#
# Next, we want to enrich our data somehow. Ultimately, the goal of structuring data is typically to perform some kind of analysis or visualization - in the case of this international conflict information, it could be valuable to plot the information graphically. To do this, we need coordinates corresponding to the articles.
#
# First, we will use **natural language processing (NLP)** and **named entity recognition (NER)** to extract place-names from the text. NLP is a form of machine learning, in which computer algorithms use grammar and syntax rules to learn relationships between words in text. Using that learning, NER is able to understand the role that certain words play within a sentence or paragraph. This tutorial is not intended to be a comprehensive introduction to NLP - for such a resource, try [this article on Medium](https://medium.com/@ODSC/an-introduction-to-natural-language-processing-nlp-8e476d9f5f59).
#
# To then find coordinates for the place names, we will use the **Open Cage API** to query for coordinates; you can make a free account and receive an API key [here](https://opencagedata.com/api). There are many other popular geo-coding APIs to choose from, but through trial and error I found Open Cage to have the best performance given the obscure place names of the Middle East.
#
# First, we iterate through each place name retrieved from the article and query it in Open Cage.
#
# *Please note that your query allotments are very limited in the free version of Open Cage. If your query errors out, try again another day or using another API.*
#
# Once this is done, we will cross-reference the Open Cage results with the **mentioned_countries** list created earlier. This will ensure that the query results we retrieve are located in the correct place.

# %%
#Uses NLP to extract place names, then queries against open-cage API to get coordinates for plotting

#Insert your own OpenCage API key here:
geo_api_key='Insert Your API Key Here'

def get_coords(content_list):
  iteration=1
  for i in range(len(content_list)):
    print('Getting coordinates',iteration,'/',len(content_list))
    temp_list=[]
    text=content_list[i]

    #Applying a NER algorithm, from the python library 'ner-d', to find place names. 

    doc=nlp(text)
    location=[X.text for X in doc.ents if X.label_ == 'GPE']
    location_dict=dict.fromkeys(location,0)
    location=list(location_dict)


    #Querying the locations in Open Cage. 
    
    for l in location:
      try: 
        request_url='https://api.opencagedata.com/geocode/v1/json?q={}&key={}'.format(l,geo_api_key)
        page=requests.get(request_url)
        data=page.json()
        for n in range(len(data)):

          #This line of code checks that the country in the query results matches one of the countries
          #in the mentioned_countries for the overall article. If not, then the query result is likely a false positive. 

          if data['results'][n]['components']['country'] in mentioned_countries[i]:
            lat=data['results'][n]['geometry']['lat']
            lng=data['results'][n]['geometry']['lng']
            coordinates={'Location': l,
                          'Lat': lat,
                          'Lon': lng}
            temp_list.append(coordinates)
            break
          else:
            continue    
      except Exception: 
        continue
    coord_list.append(temp_list)
    iteration+=1

# %% [markdown]
# ##Named Entity Recognition: People
#
# Next, we will extract the names of people mentioned in the article. To do this, we will again use the NER algorithms from the **NER-D python library**.
#
# In the final structured data, I only want full names. Wouldn't it be confusing to find a data entry with a *'mentioned person'* of "Jack" or "John"? It would be pretty much useless. To do this, we will once again employ some rudimentary statistics. The function will track full names when they are mentioned, usually in the beginning of the text. When a partial name is mentioned later, it will reference the list of full names to identify who the partial name is referencing. For example, if a news article read as follows: *"Joe Biden is running for President. Joe is best known as the Vice President for former President Barrack Obama."* We know that **Joe** is referencing **Joe Biden**, because his full name was given earlier in the text. This function will operate in that same way.
#
# In the case of duplicates, the function will use the same statistics used earlier for the country function. It will measure a count of how many times a name was mentioned, and use that as the most likely identifier. Example: *'Joe Biden and his son, Hunter Biden, are popular US politicians. Joe Biden is the former VP. Biden is now making a run for president against incumbent Donald Trump'* We know that **'Biden'** is referencing **'Joe Biden'** from context. The passage is clearly about Joe Biden, not Hunter Biden, based on the statistical focus of the text.
#
# Once the function has figured out all the full names mentioned, it will add them to a list. It will then query each name in **Wikipedia**, to verify that it is the name of an influential person worthy of being included in the structured data.

# %%
def get_people(content_list):
  iteration=1

  #Using NER to find people names in the text. 
  
  for i in range(len(content_list)):
    print('Getting people',iteration,'/',len(content_list))
    temp_list=[]
    text=content_list[i]
    doc=nlp(text)
    persons=[X.text for X in doc.ents if X.label_ == 'PERSON']
    persons_dict=dict.fromkeys(persons,0)
    persons=list(persons_dict)

    full_names=[]
    for person in persons: 
      if len(word_tokenize(person)) >= 2:
        string_name=re.sub(r"[^a-zA-Z0-9]+", ' ', person).strip()
        full_names.append(string_name)
  
    final_names=[]
    for person in persons:
      for name in full_names:
        tokens=word_tokenize(name)
        for n in range(len(tokens)):
          if person==tokens[n]:
            final_names.append(name)

    for name in full_names:
      final_names.append(name)

    name_dict=dict.fromkeys(final_names,0)
    final_names=list(name_dict)
    valid_names=[]

    for name in final_names:
      page=requests.get('https://en.wikipedia.org/wiki/'+name)
      if page.status_code==200:
        valid_names.append(name)

    people.append(valid_names)
    iteration+=1

# %% [markdown]
# ##Keyword Extraction: Term Frequency-Inverse Document Frequency
#
# Our next task is to extract keywords from the text. The most common method of doing this is by using a method called **Term Frequency-Inverse Document Frequency (TF-IDF)**. Basically, TF-IDF models measure how often a term or word was used within a single document, then compares that to its average usage throughout the entire corpus of documents. If a term is used frequently in a single document, and infrequently across the entire corpus of documents, then it is likely that term represents a keyword unique to that specific document. This guide is not meant to be a comprehensive overview of TF-IDF models. For more information, check out [this article on Medium](https://medium.com/datadriveninvestor/tf-idf-in-natural-language-processing-8db8ef4a7736).
#
# First, our function will create what is commonly known as a *'bag-of-words'*. This will track every word used in every document. Then, it will count every usage of every word in each document - the **term frequency**. Then, it takes the common logarithm of every sentence in every document containing the term - the **inverse document frequency**. Those values are then written to coordinates in a matrix, which is then sorted to help us find the words most likely to represent unique keywords for our document.

# %%
#The first function pre-processes text by lowering the case of characters, 
#and removing special characters. 

def pre_process(text):
    text=text.lower()
    text=re.sub("</?.*?>"," <> ",text)
    text=re.sub("(\\d|\\W)+"," ",text)
    return text

#This function maps matrices to coordinates. The TF-IDF function maps 
#Frequency scores to matrices, which then need to be sorted to help us find our keywords. 

def sort_coo(coo_matrix):
    tuples = zip(coo_matrix.col, coo_matrix.data)
    return sorted(tuples, key=lambda x: (x[1], x[0]), reverse=True)

#As with above, this is a helper function that will assist in the sorting and
#selection of keywords once the frequencies have been mapped to matrices. 
#This function specifically helps us to choose the most relevant keywords, 
#based on TF-IDF statistics

def extract_topn_from_vector(feature_names, sorted_items, topn=10):
    sorted_items = sorted_items[:topn]
    score_vals = []
    feature_vals = []

    for idx, score in sorted_items:
        fname = feature_names[idx]
        score_vals.append(round(score, 3))
        feature_vals.append(feature_names[idx])

    results= {}
    for idx in range(len(feature_vals)):
        results[feature_vals[idx]]=score_vals[idx]
    return results

#The final function, which incorporates the above helper functions, 
#Applies a TF-IDF algorithm to the body of our text to find keywords based
#on frequency of usage. 

def get_keywords(content_list):
  iteration=1
  processed_text=[pre_process(text) for text in content_list]
  stop_words=set(stopwords.words('english'))
  cv=CountVectorizer(max_df=0.85,stop_words=stop_words)
  word_count_vector=cv.fit_transform(processed_text)

  tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
  tfidf_transformer.fit(word_count_vector)

  feature_names=cv.get_feature_names()

  for i in range(len(processed_text)):
    print('Getting Keywords',iteration,'/',len(content_list))
    doc=processed_text[i]
    tf_idf_vector=tfidf_transformer.transform(cv.transform([doc]))
    sorted_items=sort_coo(tf_idf_vector.tocoo())
    keys=extract_topn_from_vector(feature_names,sorted_items,10)
    keywords.append(list(keys.keys()))
    iteration+=1

# %% [markdown]
# ## Topic Modeling
#
# One of the most common tasks in NLP is known as **topic modeling**. This is a form of clustering that attempts to automatically sort documents into categories based on their text content. In this specific instance, I would like to know *at-a-glance* whether ISW is writing more products about Operation Inherent Resolve in Iraq, or about the Russian intervention in Belarus. Topic modeling is the solution to this problem. By sorting articles into categories based on text content, I can easily gain an *at-a-glance* understaning of the document's main ideas.
#
# For this example, I will be using a k-means clustering algorithm to conduct topic modeling. First, I will use a TF-IDF algorithm again to vectorize each document. **Vectorization** is a machine-learning term that refers to the transformation of non-numeric data into numeric spatial data that the computer can use to conduct machine learning tasks.
#
# Once documents are vectorized, helper functions check to see what the optimal number of clusters are. *(The **k** in **k-means**)*. In this case, the optimal number was **50**. Once I found the optimal number, in this example I commented out that line of code and manually adjusted the parameters to equal 50. That is because the dataset I am analyzing does not change often, so I can expect the number of optimal clusters to stay the same over time. For data that changes more frequently, you should return the optimal number of clusters as a variable - this will help your clustering algorithm to automatically set its optimal parameters. I demonstrate an example of this in [my time-series analysis article](https://towardsdatascience.com/investigate-anomalies-in-temporal-data-with-machine-learning-b3da86793142) on Medium.
#
# Once each cluster is complete, I save the number of each cluster *(1-50)* to a list of **cluster_numbers** and the keywords making up each cluster to a list of **cluster_keywords**. These cluster keywords will be used later to add a title to each topic cluster.

# %%
#This function checks the clustering algorithm against various 'k' parameters 
#to find the optimal value of 'k'. 

def find_optimal_clusters(data, max_k):
    iters = range(2, max_k+1, 2)
    
    sse = []
    for k in iters:
        sse.append(MiniBatchKMeans(n_clusters=k, 
                                   init_size=1024, 
                                   batch_size=2048,
                                   random_state=20).fit(data).inertia_)
        
        print('Fit {} clusters'.format(k))
        
    f, ax = plt.subplots(1, 1)
    ax.plot(iters, sse, marker='o')
    ax.set_xlabel('Cluster Centers')
    ax.set_xticks(iters)
    ax.set_xticklabels(iters)
    ax.set_ylabel('SSE')
    ax.set_title('SSE by Cluster Center Plot')

#Getting keywords from content lists, 
#to help with categorizing topic clusters later

def get_top_keywords(data, clusters, labels, n_terms):
  df = pd.DataFrame(data.todense()).groupby(clusters).mean()
  for i,r in df.iterrows():
    cluster_keywords.append(','.join([labels[t] for t in np.argsort(r)[-n_terms:]]))
    
#Applying clustering to content lists for topic modeling

def get_topics(content_list):
  processed_text=[pre_process(text) for text in content_list]
  stop_words=set(stopwords.words('english'))
  cv=CountVectorizer(max_df=0.85,stop_words=stop_words)
  word_count_vector=cv.fit_transform(processed_text)

  tfidf_transformer=TfidfTransformer(smooth_idf=True,use_idf=True)
  tfidf_transformer.fit(word_count_vector)

  feature_names=cv.get_feature_names()
  vector=tfidf_transformer.transform(cv.transform(processed_text))

  #find_optimal_clusters(vector,50)

  clusters = MiniBatchKMeans(n_clusters=50, init_size=1024, batch_size=2048, random_state=20).fit_predict(vector)
  for cluster in clusters:
    cluster_number.append(int(cluster))
  
  get_top_keywords(vector, clusters, cv.get_feature_names(), 20)

# %% [markdown]
# #Putting it Together
#
# Finally, we will extract our data. Using the list of **hrefs** we got earlier, it is time to apply all of our extraction functions to the web content.

# %%
#Iterate through the hrefs extracted from 'browse', extract pertinent content 

iteration=1

#The first few functions rely on the original extracted web content as a parameter.
#These are all basic web-scraping techniques. 

for href in hrefs:
  print('Web scraping: iteration',iteration,'/',len(hrefs))
  page=requests.get(href)
  soup=BeautifulSoup(page.text,'html.parser')
  links.append(href)
  get_date(soup)
  get_title(soup)
  get_contents(soup)
  iteration+=1

#These next functions rely on the body of our text as a parameter.
#These are the NLP-based functions. 

#Note: Because of the querying of an external API, 
#a timeout is required to stop from overloading the server. 
#This portion of the code takes a very long time to run.

get_countries(content_text)
get_coords(content_text)
get_people(content_text)
get_keywords(content_text)
get_topics(content_text)
# Out:
# Streaming output truncated to the last 5000 lines.
# Getting coordinates 237 / 1745
# Getting coordinates 238 / 1745
# Getting coordinates 239 / 1745
# Getting coordinates 240 / 1745
# Getting coordinates 241 / 1745
# Getting coordinates 242 / 1745
# Getting coordinates 243 / 1745
# Getting coordinates 244 / 1745
# Getting coordinates 245 / 1745
# Getting coordinates 246 / 1745
# Getting coordinates 247 / 1745
# Getting coordinates 248 / 1745
# Getting coordinates 249 / 1745
# Getting coordinates 250 / 1745
# Getting coordinates 251 / 1745
# Getting coordinates 252 / 1745
# Getting coordinates 253 / 1745
# Getting coordinates 254 / 1745
# Getting coordinates 255 / 1745
# Getting coordinates 256 / 1745
# Getting coordinates 257 / 1745
# Getting coordinates 258 / 1745
# Getting coordinates 259 / 1745
# Getting coordinates 260 / 1745
# Getting coordinates 261 / 1745
# Getting coordinates 262 / 1745
# Getting coordinates 263 / 1745
# Getting coordinates 264 / 1745
# Getting coordinates 265 / 1745
# Getting coordinates 266 / 1745
# Getting coordinates 267 / 1745
# Getting coordinates 268 / 1745
# Getting coordinates 269 / 1745
# Getting coordinates 270 / 1745
# Getting coordinates 271 / 1745
# Getting coordinates 272 / 1745
# Getting coordinates 273 / 1745
# Getting coordinates 274 / 1745
# Getting coordinates 275 / 1745
# Getting coordinates 276 / 1745
# Getting coordinates 277 / 1745
# Getting coordinates 278 / 1745
# Getting coordinates 279 / 1745
# Getting coordinates 280 / 1745
# Getting coordinates 281 / 1745
# Getting coordinates 282 / 1745
# Getting coordinates 283 / 1745
# Getting coordinates 284 / 1745
# Getting coordinates 285 / 1745
# Getting coordinates 286 / 1745
# Getting coordinates 287 / 1745
# Getting coordinates 288 / 1745
# Getting coordinates 289 / 1745
# Getting coordinates 290 / 1745
# Getting coordinates 291 / 1745
# Getting coordinates 292 / 1745
# Getting coordinates 293 / 1745
# Getting coordinates 294 / 1745
# Getting coordinates 295 / 1745
# Getting coordinates 296 / 1745
# Getting coordinates 297 / 1745
# Getting coordinates 298 / 1745
# Getting coordinates 299 / 1745
# Getting coordinates 300 / 1745
# Getting coordinates 301 / 1745
# Getting coordinates 302 / 1745
# Getting coordinates 303 / 1745
# Getting coordinates 304 / 1745
# Getting coordinates 305 / 1745
# Getting coordinates 306 / 1745
# Getting coordinates 307 / 1745
# Getting coordinates 308 / 1745
# Getting coordinates 309 / 1745
# Getting coordinates 310 / 1745
# Getting coordinates 311 / 1745
# Getting coordinates 312 / 1745
# Getting coordinates 313 / 1745
# Getting coordinates 314 / 1745
# Getting coordinates 315 / 1745
# Getting coordinates 316 / 1745
# Getting coordinates 317 / 1745
# Getting coordinates 318 / 1745
# Getting coordinates 319 / 1745
# Getting coordinates 320 / 1745
# Getting coordinates 321 / 1745
# Getting coordinates 322 / 1745
# Getting coordinates 323 / 1745
# Getting coordinates 324 / 1745
# Getting coordinates 325 / 1745
# Getting coordinates 326 / 1745
# Getting coordinates 327 / 1745
# Getting coordinates 328 / 1745
# Getting coordinates 329 / 1745
# Getting coordinates 330 / 1745
# Getting coordinates 331 / 1745
# Getting coordinates 332 / 1745
# Getting coordinates 333 / 1745
# Getting coordinates 334 / 1745
# Getting coordinates 335 / 1745
# Getting coordinates 336 / 1745
# Getting coordinates 337 / 1745
# Getting coordinates 338 / 1745
# Getting coordinates 339 / 1745
# Getting coordinates 340 / 1745
# Getting coordinates 341 / 1745
# Getting coordinates 342 / 1745
# Getting coordinates 343 / 1745
# Getting coordinates 344 / 1745
# Getting coordinates 345 / 1745
# Getting coordinates 346 / 1745
# Getting coordinates 347 / 1745
# Getting coordinates 348 / 1745
# Getting coordinates 349 / 1745
# Getting coordinates 350 / 1745
# Getting coordinates 351 / 1745
# Getting coordinates 352 / 1745
# Getting coordinates 353 / 1745
# Getting coordinates 354 / 1745
# Getting coordinates 355 / 1745
# Getting coordinates 356 / 1745
# Getting coordinates 357 / 1745
# Getting coordinates 358 / 1745
# Getting coordinates 359 / 1745
# Getting coordinates 360 / 1745
# Getting coordinates 361 / 1745
# Getting coordinates 362 / 1745
# Getting coordinates 363 / 1745
# Getting coordinates 364 / 1745
# Getting coordinates 365 / 1745
# Getting coordinates 366 / 1745
# Getting coordinates 367 / 1745
# Getting coordinates 368 / 1745
# Getting coordinates 369 / 1745
# Getting coordinates 370 / 1745
# Getting coordinates 371 / 1745
# Getting coordinates 372 / 1745
# Getting coordinates 373 / 1745
# Getting coordinates 374 / 1745
# Getting coordinates 375 / 1745
# Getting coordinates 376 / 1745
# Getting coordinates 377 / 1745
# Getting coordinates 378 / 1745
# Getting coordinates 379 / 1745
# Getting coordinates 380 / 1745
# Getting coordinates 381 / 1745
# Getting coordinates 382 / 1745
# Getting coordinates 383 / 1745
# Getting coordinates 384 / 1745
# Getting coordinates 385 / 1745
# Getting coordinates 386 / 1745
# Getting coordinates 387 / 1745
# Getting coordinates 388 / 1745
# Getting coordinates 389 / 1745
# Getting coordinates 390 / 1745
# Getting coordinates 391 / 1745
# Getting coordinates 392 / 1745
# Getting coordinates 393 / 1745
# Getting coordinates 394 / 1745
# Getting coordinates 395 / 1745
# Getting coordinates 396 / 1745
# Getting coordinates 397 / 1745
# Getting coordinates 398 / 1745
# Getting coordinates 399 / 1745
# Getting coordinates 400 / 1745
# Getting coordinates 401 / 1745
# Getting coordinates 402 / 1745
# Getting coordinates 403 / 1745
# Getting coordinates 404 / 1745
# Getting coordinates 405 / 1745
# Getting coordinates 406 / 1745
# Getting coordinates 407 / 1745
# Getting coordinates 408 / 1745
# Getting coordinates 409 / 1745
# Getting coordinates 410 / 1745
# Getting coordinates 411 / 1745
# Getting coordinates 412 / 1745
# Getting coordinates 413 / 1745
# Getting coordinates 414 / 1745
# Getting coordinates 415 / 1745
# Getting coordinates 416 / 1745
# Getting coordinates 417 / 1745
# Getting coordinates 418 / 1745
# Getting coordinates 419 / 1745
# Getting coordinates 420 / 1745
# Getting coordinates 421 / 1745
# Getting coordinates 422 / 1745
# Getting coordinates 423 / 1745
# Getting coordinates 424 / 1745
# Getting coordinates 425 / 1745
# Getting coordinates 426 / 1745
# Getting coordinates 427 / 1745
# Getting coordinates 428 / 1745
# Getting coordinates 429 / 1745
# Getting coordinates 430 / 1745
# Getting coordinates 431 / 1745
# Getting coordinates 432 / 1745
# Getting coordinates 433 / 1745
# Getting coordinates 434 / 1745
# Getting coordinates 435 / 1745
# Getting coordinates 436 / 1745
# Getting coordinates 437 / 1745
# Getting coordinates 438 / 1745
# Getting coordinates 439 / 1745
# Getting coordinates 440 / 1745
# Getting coordinates 441 / 1745
# Getting coordinates 442 / 1745
# Getting coordinates 443 / 1745
# Getting coordinates 444 / 1745
# Getting coordinates 445 / 1745
# Getting coordinates 446 / 1745
# Getting coordinates 447 / 1745
# Getting coordinates 448 / 1745
# Getting coordinates 449 / 1745
# Getting coordinates 450 / 1745
# Getting coordinates 451 / 1745
# Getting coordinates 452 / 1745
# Getting coordinates 453 / 1745
# Getting coordinates 454 / 1745
# Getting coordinates 455 / 1745
# Getting coordinates 456 / 1745
# Getting coordinates 457 / 1745
# Getting coordinates 458 / 1745
# Getting coordinates 459 / 1745
# Getting coordinates 460 / 1745
# Getting coordinates 461 / 1745
# Getting coordinates 462 / 1745
# Getting coordinates 463 / 1745
# Getting coordinates 464 / 1745
# Getting coordinates 465 / 1745
# Getting coordinates 466 / 1745
# Getting coordinates 467 / 1745
# Getting coordinates 468 / 1745
# Getting coordinates 469 / 1745
# Getting coordinates 470 / 1745
# Getting coordinates 471 / 1745
# Getting coordinates 472 / 1745
# Getting coordinates 473 / 1745
# Getting coordinates 474 / 1745
# Getting coordinates 475 / 1745
# Getting coordinates 476 / 1745
# Getting coordinates 477 / 1745
# Getting coordinates 478 / 1745
# Getting coordinates 479 / 1745
# Getting coordinates 480 / 1745
# Getting coordinates 481 / 1745
# Getting coordinates 482 / 1745
# Getting coordinates 483 / 1745
# Getting coordinates 484 / 1745
# Getting coordinates 485 / 1745
# Getting coordinates 486 / 1745
# Getting coordinates 487 / 1745
# Getting coordinates 488 / 1745
# Getting coordinates 489 / 1745
# Getting coordinates 490 / 1745
# Getting coordinates 491 / 1745
# Getting coordinates 492 / 1745
# Getting coordinates 493 / 1745
# Getting coordinates 494 / 1745
# Getting coordinates 495 / 1745
# Getting coordinates 496 / 1745
# Getting coordinates 497 / 1745
# Getting coordinates 498 / 1745
# Getting coordinates 499 / 1745
# Getting coordinates 500 / 1745
# Getting coordinates 501 / 1745
# Getting coordinates 502 / 1745
# Getting coordinates 503 / 1745
# Getting coordinates 504 / 1745
# Getting coordinates 505 / 1745
# Getting coordinates 506 / 1745
# Getting coordinates 507 / 1745
# Getting coordinates 508 / 1745
# Getting coordinates 509 / 1745
# Getting coordinates 510 / 1745
# Getting coordinates 511 / 1745
# Getting coordinates 512 / 1745
# Getting coordinates 513 / 1745
# Getting coordinates 514 / 1745
# Getting coordinates 515 / 1745
# Getting coordinates 516 / 1745
# Getting coordinates 517 / 1745
# Getting coordinates 518 / 1745
# Getting coordinates 519 / 1745
# Getting coordinates 520 / 1745
# Getting coordinates 521 / 1745
# Getting coordinates 522 / 1745
# Getting coordinates 523 / 1745
# Getting coordinates 524 / 1745
# Getting coordinates 525 / 1745
# Getting coordinates 526 / 1745
# Getting coordinates 527 / 1745
# Getting coordinates 528 / 1745
# Getting coordinates 529 / 1745
# Getting coordinates 530 / 1745
# Getting coordinates 531 / 1745
# Getting coordinates 532 / 1745
# Getting coordinates 533 / 1745
# Getting coordinates 534 / 1745
# Getting coordinates 535 / 1745
# Getting coordinates 536 / 1745
# Getting coordinates 537 / 1745
# Getting coordinates 538 / 1745
# Getting coordinates 539 / 1745
# Getting coordinates 540 / 1745
# Getting coordinates 541 / 1745
# Getting coordinates 542 / 1745
# Getting coordinates 543 / 1745
# Getting coordinates 544 / 1745
# Getting coordinates 545 / 1745
# Getting coordinates 546 / 1745
# Getting coordinates 547 / 1745
# Getting coordinates 548 / 1745
# Getting coordinates 549 / 1745
# Getting coordinates 550 / 1745
# Getting coordinates 551 / 1745
# Getting coordinates 552 / 1745
# Getting coordinates 553 / 1745
# Getting coordinates 554 / 1745
# Getting coordinates 555 / 1745
# Getting coordinates 556 / 1745
# Getting coordinates 557 / 1745
# Getting coordinates 558 / 1745
# Getting coordinates 559 / 1745
# Getting coordinates 560 / 1745
# Getting coordinates 561 / 1745
# Getting coordinates 562 / 1745
# Getting coordinates 563 / 1745
# Getting coordinates 564 / 1745
# Getting coordinates 565 / 1745
# Getting coordinates 566 / 1745
# Getting coordinates 567 / 1745
# Getting coordinates 568 / 1745
# Getting coordinates 569 / 1745
# Getting coordinates 570 / 1745
# Getting coordinates 571 / 1745
# Getting coordinates 572 / 1745
# Getting coordinates 573 / 1745
# Getting coordinates 574 / 1745
# Getting coordinates 575 / 1745
# Getting coordinates 576 / 1745
# Getting coordinates 577 / 1745
# Getting coordinates 578 / 1745
# Getting coordinates 579 / 1745
# Getting coordinates 580 / 1745
# Getting coordinates 581 / 1745
# Getting coordinates 582 / 1745
# Getting coordinates 583 / 1745
# Getting coordinates 584 / 1745
# Getting coordinates 585 / 1745
# Getting coordinates 586 / 1745
# Getting coordinates 587 / 1745
# Getting coordinates 588 / 1745
# Getting coordinates 589 / 1745
# Getting coordinates 590 / 1745
# Getting coordinates 591 / 1745
# Getting coordinates 592 / 1745
# Getting coordinates 593 / 1745
# Getting coordinates 594 / 1745
# Getting coordinates 595 / 1745
# Getting coordinates 596 / 1745
# Getting coordinates 597 / 1745
# Getting coordinates 598 / 1745
# Getting coordinates 599 / 1745
# Getting coordinates 600 / 1745
# Getting coordinates 601 / 1745
# Getting coordinates 602 / 1745
# Getting coordinates 603 / 1745
# Getting coordinates 604 / 1745
# Getting coordinates 605 / 1745
# Getting coordinates 606 / 1745
# Getting coordinates 607 / 1745
# Getting coordinates 608 / 1745
# Getting coordinates 609 / 1745
# Getting coordinates 610 / 1745
# Getting coordinates 611 / 1745
# Getting coordinates 612 / 1745
# Getting coordinates 613 / 1745
# Getting coordinates 614 / 1745
# Getting coordinates 615 / 1745
# Getting coordinates 616 / 1745
# Getting coordinates 617 / 1745
# Getting coordinates 618 / 1745
# Getting coordinates 619 / 1745
# Getting coordinates 620 / 1745
# Getting coordinates 621 / 1745
# Getting coordinates 622 / 1745
# Getting coordinates 623 / 1745
# Getting coordinates 624 / 1745
# Getting coordinates 625 / 1745
# Getting coordinates 626 / 1745
# Getting coordinates 627 / 1745
# Getting coordinates 628 / 1745
# Getting coordinates 629 / 1745
# Getting coordinates 630 / 1745
# Getting coordinates 631 / 1745
# Getting coordinates 632 / 1745
# Getting coordinates 633 / 1745
# Getting coordinates 634 / 1745
# Getting coordinates 635 / 1745
# Getting coordinates 636 / 1745
# Getting coordinates 637 / 1745
# Getting coordinates 638 / 1745
# Getting coordinates 639 / 1745
# Getting coordinates 640 / 1745
# Getting coordinates 641 / 1745
# Getting coordinates 642 / 1745
# Getting coordinates 643 / 1745
# Getting coordinates 644 / 1745
# Getting coordinates 645 / 1745
# Getting coordinates 646 / 1745
# Getting coordinates 647 / 1745
# Getting coordinates 648 / 1745
# Getting coordinates 649 / 1745
# Getting coordinates 650 / 1745
# Getting coordinates 651 / 1745
# Getting coordinates 652 / 1745
# Getting coordinates 653 / 1745
# Getting coordinates 654 / 1745
# Getting coordinates 655 / 1745
# Getting coordinates 656 / 1745
# Getting coordinates 657 / 1745
# Getting coordinates 658 / 1745
# Getting coordinates 659 / 1745
# Getting coordinates 660 / 1745
# Getting coordinates 661 / 1745
# Getting coordinates 662 / 1745
# Getting coordinates 663 / 1745
# Getting coordinates 664 / 1745
# Getting coordinates 665 / 1745
# Getting coordinates 666 / 1745
# Getting coordinates 667 / 1745
# Getting coordinates 668 / 1745
# Getting coordinates 669 / 1745
# Getting coordinates 670 / 1745
# Getting coordinates 671 / 1745
# Getting coordinates 672 / 1745
# Getting coordinates 673 / 1745
# Getting coordinates 674 / 1745
# Getting coordinates 675 / 1745
# Getting coordinates 676 / 1745
# Getting coordinates 677 / 1745
# Getting coordinates 678 / 1745
# Getting coordinates 679 / 1745
# Getting coordinates 680 / 1745
# Getting coordinates 681 / 1745
# Getting coordinates 682 / 1745
# Getting coordinates 683 / 1745
# Getting coordinates 684 / 1745
# Getting coordinates 685 / 1745
# Getting coordinates 686 / 1745
# Getting coordinates 687 / 1745
# Getting coordinates 688 / 1745
# Getting coordinates 689 / 1745
# Getting coordinates 690 / 1745
# Getting coordinates 691 / 1745
# Getting coordinates 692 / 1745
# Getting coordinates 693 / 1745
# Getting coordinates 694 / 1745
# Getting coordinates 695 / 1745
# Getting coordinates 696 / 1745
# Getting coordinates 697 / 1745
# Getting coordinates 698 / 1745
# Getting coordinates 699 / 1745
# Getting coordinates 700 / 1745
# Getting coordinates 701 / 1745
# Getting coordinates 702 / 1745
# Getting coordinates 703 / 1745
# Getting coordinates 704 / 1745
# Getting coordinates 705 / 1745
# Getting coordinates 706 / 1745
# Getting coordinates 707 / 1745
# Getting coordinates 708 / 1745
# Getting coordinates 709 / 1745
# Getting coordinates 710 / 1745
# Getting coordinates 711 / 1745
# Getting coordinates 712 / 1745
# Getting coordinates 713 / 1745
# Getting coordinates 714 / 1745
# Getting coordinates 715 / 1745
# Getting coordinates 716 / 1745
# Getting coordinates 717 / 1745
# Getting coordinates 718 / 1745
# Getting coordinates 719 / 1745
# Getting coordinates 720 / 1745
# Getting coordinates 721 / 1745
# Getting coordinates 722 / 1745
# Getting coordinates 723 / 1745
# Getting coordinates 724 / 1745
# Getting coordinates 725 / 1745
# Getting coordinates 726 / 1745
# Getting coordinates 727 / 1745
# Getting coordinates 728 / 1745
# Getting coordinates 729 / 1745
# Getting coordinates 730 / 1745
# Getting coordinates 731 / 1745
# Getting coordinates 732 / 1745
# Getting coordinates 733 / 1745
# Getting coordinates 734 / 1745
# Getting coordinates 735 / 1745
# Getting coordinates 736 / 1745
# Getting coordinates 737 / 1745
# Getting coordinates 738 / 1745
# Getting coordinates 739 / 1745
# Getting coordinates 740 / 1745
# Getting coordinates 741 / 1745
# Getting coordinates 742 / 1745
# Getting coordinates 743 / 1745
# Getting coordinates 744 / 1745
# Getting coordinates 745 / 1745
# Getting coordinates 746 / 1745
# Getting coordinates 747 / 1745
# Getting coordinates 748 / 1745
# Getting coordinates 749 / 1745
# Getting coordinates 750 / 1745
# Getting coordinates 751 / 1745
# Getting coordinates 752 / 1745
# Getting coordinates 753 / 1745
# Getting coordinates 754 / 1745
# Getting coordinates 755 / 1745
# Getting coordinates 756 / 1745
# Getting coordinates 757 / 1745
# Getting coordinates 758 / 1745
# Getting coordinates 759 / 1745
# Getting coordinates 760 / 1745
# Getting coordinates 761 / 1745
# Getting coordinates 762 / 1745
# Getting coordinates 763 / 1745
# Getting coordinates 764 / 1745
# Getting coordinates 765 / 1745
# Getting coordinates 766 / 1745
# Getting coordinates 767 / 1745
# Getting coordinates 768 / 1745
# Getting coordinates 769 / 1745
# Getting coordinates 770 / 1745
# Getting coordinates 771 / 1745
# Getting coordinates 772 / 1745
# Getting coordinates 773 / 1745
# Getting coordinates 774 / 1745
# Getting coordinates 775 / 1745
# Getting coordinates 776 / 1745
# Getting coordinates 777 / 1745
# Getting coordinates 778 / 1745
# Getting coordinates 779 / 1745
# Getting coordinates 780 / 1745
# Getting coordinates 781 / 1745
# Getting coordinates 782 / 1745
# Getting coordinates 783 / 1745
# Getting coordinates 784 / 1745
# Getting coordinates 785 / 1745
# Getting coordinates 786 / 1745
# Getting coordinates 787 / 1745
# Getting coordinates 788 / 1745
# Getting coordinates 789 / 1745
# Getting coordinates 790 / 1745
# Getting coordinates 791 / 1745
# Getting coordinates 792 / 1745
# Getting coordinates 793 / 1745
# Getting coordinates 794 / 1745
# Getting coordinates 795 / 1745
# Getting coordinates 796 / 1745
# Getting coordinates 797 / 1745
# Getting coordinates 798 / 1745
# Getting coordinates 799 / 1745
# Getting coordinates 800 / 1745
# Getting coordinates 801 / 1745
# Getting coordinates 802 / 1745
# Getting coordinates 803 / 1745
# Getting coordinates 804 / 1745
# Getting coordinates 805 / 1745
# Getting coordinates 806 / 1745
# Getting coordinates 807 / 1745
# Getting coordinates 808 / 1745
# Getting coordinates 809 / 1745
# Getting coordinates 810 / 1745
# Getting coordinates 811 / 1745
# Getting coordinates 812 / 1745
# Getting coordinates 813 / 1745
# Getting coordinates 814 / 1745
# Getting coordinates 815 / 1745
# Getting coordinates 816 / 1745
# Getting coordinates 817 / 1745
# Getting coordinates 818 / 1745
# Getting coordinates 819 / 1745
# Getting coordinates 820 / 1745
# Getting coordinates 821 / 1745
# Getting coordinates 822 / 1745
# Getting coordinates 823 / 1745
# Getting coordinates 824 / 1745
# Getting coordinates 825 / 1745
# Getting coordinates 826 / 1745
# Getting coordinates 827 / 1745
# Getting coordinates 828 / 1745
# Getting coordinates 829 / 1745
# Getting coordinates 830 / 1745
# Getting coordinates 831 / 1745
# Getting coordinates 832 / 1745
# Getting coordinates 833 / 1745
# Getting coordinates 834 / 1745
# Getting coordinates 835 / 1745
# Getting coordinates 836 / 1745
# Getting coordinates 837 / 1745
# Getting coordinates 838 / 1745
# Getting coordinates 839 / 1745
# Getting coordinates 840 / 1745
# Getting coordinates 841 / 1745
# Getting coordinates 842 / 1745
# Getting coordinates 843 / 1745
# Getting coordinates 844 / 1745
# Getting coordinates 845 / 1745
# Getting coordinates 846 / 1745
# Getting coordinates 847 / 1745
# Getting coordinates 848 / 1745
# Getting coordinates 849 / 1745
# Getting coordinates 850 / 1745
# Getting coordinates 851 / 1745
# Getting coordinates 852 / 1745
# Getting coordinates 853 / 1745
# Getting coordinates 854 / 1745
# Getting coordinates 855 / 1745
# Getting coordinates 856 / 1745
# Getting coordinates 857 / 1745
# Getting coordinates 858 / 1745
# Getting coordinates 859 / 1745
# Getting coordinates 860 / 1745
# Getting coordinates 861 / 1745
# Getting coordinates 862 / 1745
# Getting coordinates 863 / 1745
# Getting coordinates 864 / 1745
# Getting coordinates 865 / 1745
# Getting coordinates 866 / 1745
# Getting coordinates 867 / 1745
# Getting coordinates 868 / 1745
# Getting coordinates 869 / 1745
# Getting coordinates 870 / 1745
# Getting coordinates 871 / 1745
# Getting coordinates 872 / 1745
# Getting coordinates 873 / 1745
# Getting coordinates 874 / 1745
# Getting coordinates 875 / 1745
# Getting coordinates 876 / 1745
# Getting coordinates 877 / 1745
# Getting coordinates 878 / 1745
# Getting coordinates 879 / 1745
# Getting coordinates 880 / 1745
# Getting coordinates 881 / 1745
# Getting coordinates 882 / 1745
# Getting coordinates 883 / 1745
# Getting coordinates 884 / 1745
# Getting coordinates 885 / 1745
# Getting coordinates 886 / 1745
# Getting coordinates 887 / 1745
# Getting coordinates 888 / 1745
# Getting coordinates 889 / 1745
# Getting coordinates 890 / 1745
# Getting coordinates 891 / 1745
# Getting coordinates 892 / 1745
# Getting coordinates 893 / 1745
# Getting coordinates 894 / 1745
# Getting coordinates 895 / 1745
# Getting coordinates 896 / 1745
# Getting coordinates 897 / 1745
# Getting coordinates 898 / 1745
# Getting coordinates 899 / 1745
# Getting coordinates 900 / 1745
# Getting coordinates 901 / 1745
# Getting coordinates 902 / 1745
# Getting coordinates 903 / 1745
# Getting coordinates 904 / 1745
# Getting coordinates 905 / 1745
# Getting coordinates 906 / 1745
# Getting coordinates 907 / 1745
# Getting coordinates 908 / 1745
# Getting coordinates 909 / 1745
# Getting coordinates 910 / 1745
# Getting coordinates 911 / 1745
# Getting coordinates 912 / 1745
# Getting coordinates 913 / 1745
# Getting coordinates 914 / 1745
# Getting coordinates 915 / 1745
# Getting coordinates 916 / 1745
# Getting coordinates 917 / 1745
# Getting coordinates 918 / 1745
# Getting coordinates 919 / 1745
# Getting coordinates 920 / 1745
# Getting coordinates 921 / 1745
# Getting coordinates 922 / 1745
# Getting coordinates 923 / 1745
# Getting coordinates 924 / 1745
# Getting coordinates 925 / 1745
# Getting coordinates 926 / 1745
# Getting coordinates 927 / 1745
# Getting coordinates 928 / 1745
# Getting coordinates 929 / 1745
# Getting coordinates 930 / 1745
# Getting coordinates 931 / 1745
# Getting coordinates 932 / 1745
# Getting coordinates 933 / 1745
# Getting coordinates 934 / 1745
# Getting coordinates 935 / 1745
# Getting coordinates 936 / 1745
# Getting coordinates 937 / 1745
# Getting coordinates 938 / 1745
# Getting coordinates 939 / 1745
# Getting coordinates 940 / 1745
# Getting coordinates 941 / 1745
# Getting coordinates 942 / 1745
# Getting coordinates 943 / 1745
# Getting coordinates 944 / 1745
# Getting coordinates 945 / 1745
# Getting coordinates 946 / 1745
# Getting coordinates 947 / 1745
# Getting coordinates 948 / 1745
# Getting coordinates 949 / 1745
# Getting coordinates 950 / 1745
# Getting coordinates 951 / 1745
# Getting coordinates 952 / 1745
# Getting coordinates 953 / 1745
# Getting coordinates 954 / 1745
# Getting coordinates 955 / 1745
# Getting coordinates 956 / 1745
# Getting coordinates 957 / 1745
# Getting coordinates 958 / 1745
# Getting coordinates 959 / 1745
# Getting coordinates 960 / 1745
# Getting coordinates 961 / 1745
# Getting coordinates 962 / 1745
# Getting coordinates 963 / 1745
# Getting coordinates 964 / 1745
# Getting coordinates 965 / 1745
# Getting coordinates 966 / 1745
# Getting coordinates 967 / 1745
# Getting coordinates 968 / 1745
# Getting coordinates 969 / 1745
# Getting coordinates 970 / 1745
# Getting coordinates 971 / 1745
# Getting coordinates 972 / 1745
# Getting coordinates 973 / 1745
# Getting coordinates 974 / 1745
# Getting coordinates 975 / 1745
# Getting coordinates 976 / 1745
# Getting coordinates 977 / 1745
# Getting coordinates 978 / 1745
# Getting coordinates 979 / 1745
# Getting coordinates 980 / 1745
# Getting coordinates 981 / 1745
# Getting coordinates 982 / 1745
# Getting coordinates 983 / 1745
# Getting coordinates 984 / 1745
# Getting coordinates 985 / 1745
# Getting coordinates 986 / 1745
# Getting coordinates 987 / 1745
# Getting coordinates 988 / 1745
# Getting coordinates 989 / 1745
# Getting coordinates 990 / 1745
# Getting coordinates 991 / 1745
# Getting coordinates 992 / 1745
# Getting coordinates 993 / 1745
# Getting coordinates 994 / 1745
# Getting coordinates 995 / 1745
# Getting coordinates 996 / 1745
# Getting coordinates 997 / 1745
# Getting coordinates 998 / 1745
# Getting coordinates 999 / 1745
# Getting coordinates 1000 / 1745
# Getting coordinates 1001 / 1745
# Getting coordinates 1002 / 1745
# Getting coordinates 1003 / 1745
# Getting coordinates 1004 / 1745
# Getting coordinates 1005 / 1745
# Getting coordinates 1006 / 1745
# Getting coordinates 1007 / 1745
# Getting coordinates 1008 / 1745
# Getting coordinates 1009 / 1745
# Getting coordinates 1010 / 1745
# Getting coordinates 1011 / 1745
# Getting coordinates 1012 / 1745
# Getting coordinates 1013 / 1745
# Getting coordinates 1014 / 1745
# Getting coordinates 1015 / 1745
# Getting coordinates 1016 / 1745
# Getting coordinates 1017 / 1745
# Getting coordinates 1018 / 1745
# Getting coordinates 1019 / 1745
# Getting coordinates 1020 / 1745
# Getting coordinates 1021 / 1745
# Getting coordinates 1022 / 1745
# Getting coordinates 1023 / 1745
# Getting coordinates 1024 / 1745
# Getting coordinates 1025 / 1745
# Getting coordinates 1026 / 1745
# Getting coordinates 1027 / 1745
# Getting coordinates 1028 / 1745
# Getting coordinates 1029 / 1745
# Getting coordinates 1030 / 1745
# Getting coordinates 1031 / 1745
# Getting coordinates 1032 / 1745
# Getting coordinates 1033 / 1745
# Getting coordinates 1034 / 1745
# Getting coordinates 1035 / 1745
# Getting coordinates 1036 / 1745
# Getting coordinates 1037 / 1745
# Getting coordinates 1038 / 1745
# Getting coordinates 1039 / 1745
# Getting coordinates 1040 / 1745
# Getting coordinates 1041 / 1745
# Getting coordinates 1042 / 1745
# Getting coordinates 1043 / 1745
# Getting coordinates 1044 / 1745
# Getting coordinates 1045 / 1745
# Getting coordinates 1046 / 1745
# Getting coordinates 1047 / 1745
# Getting coordinates 1048 / 1745
# Getting coordinates 1049 / 1745
# Getting coordinates 1050 / 1745
# Getting coordinates 1051 / 1745
# Getting coordinates 1052 / 1745
# Getting coordinates 1053 / 1745
# Getting coordinates 1054 / 1745
# Getting coordinates 1055 / 1745
# Getting coordinates 1056 / 1745
# Getting coordinates 1057 / 1745
# Getting coordinates 1058 / 1745
# Getting coordinates 1059 / 1745
# Getting coordinates 1060 / 1745
# Getting coordinates 1061 / 1745
# Getting coordinates 1062 / 1745
# Getting coordinates 1063 / 1745
# Getting coordinates 1064 / 1745
# Getting coordinates 1065 / 1745
# Getting coordinates 1066 / 1745
# Getting coordinates 1067 / 1745
# Getting coordinates 1068 / 1745
# Getting coordinates 1069 / 1745
# Getting coordinates 1070 / 1745
# Getting coordinates 1071 / 1745
# Getting coordinates 1072 / 1745
# Getting coordinates 1073 / 1745
# Getting coordinates 1074 / 1745
# Getting coordinates 1075 / 1745
# Getting coordinates 1076 / 1745
# Getting coordinates 1077 / 1745
# Getting coordinates 1078 / 1745
# Getting coordinates 1079 / 1745
# Getting coordinates 1080 / 1745
# Getting coordinates 1081 / 1745
# Getting coordinates 1082 / 1745
# Getting coordinates 1083 / 1745
# Getting coordinates 1084 / 1745
# Getting coordinates 1085 / 1745
# Getting coordinates 1086 / 1745
# Getting coordinates 1087 / 1745
# Getting coordinates 1088 / 1745
# Getting coordinates 1089 / 1745
# Getting coordinates 1090 / 1745
# Getting coordinates 1091 / 1745
# Getting coordinates 1092 / 1745
# Getting coordinates 1093 / 1745
# Getting coordinates 1094 / 1745
# Getting coordinates 1095 / 1745
# Getting coordinates 1096 / 1745
# Getting coordinates 1097 / 1745
# Getting coordinates 1098 / 1745
# Getting coordinates 1099 / 1745
# Getting coordinates 1100 / 1745
# Getting coordinates 1101 / 1745
# Getting coordinates 1102 / 1745
# Getting coordinates 1103 / 1745
# Getting coordinates 1104 / 1745
# Getting coordinates 1105 / 1745
# Getting coordinates 1106 / 1745
# Getting coordinates 1107 / 1745
# Getting coordinates 1108 / 1745
# Getting coordinates 1109 / 1745
# Getting coordinates 1110 / 1745
# Getting coordinates 1111 / 1745
# Getting coordinates 1112 / 1745
# Getting coordinates 1113 / 1745
# Getting coordinates 1114 / 1745
# Getting coordinates 1115 / 1745
# Getting coordinates 1116 / 1745
# Getting coordinates 1117 / 1745
# Getting coordinates 1118 / 1745
# Getting coordinates 1119 / 1745
# Getting coordinates 1120 / 1745
# Getting coordinates 1121 / 1745
# Getting coordinates 1122 / 1745
# Getting coordinates 1123 / 1745
# Getting coordinates 1124 / 1745
# Getting coordinates 1125 / 1745
# Getting coordinates 1126 / 1745
# Getting coordinates 1127 / 1745
# Getting coordinates 1128 / 1745
# Getting coordinates 1129 / 1745
# Getting coordinates 1130 / 1745
# Getting coordinates 1131 / 1745
# Getting coordinates 1132 / 1745
# Getting coordinates 1133 / 1745
# Getting coordinates 1134 / 1745
# Getting coordinates 1135 / 1745
# Getting coordinates 1136 / 1745
# Getting coordinates 1137 / 1745
# Getting coordinates 1138 / 1745
# Getting coordinates 1139 / 1745
# Getting coordinates 1140 / 1745
# Getting coordinates 1141 / 1745
# Getting coordinates 1142 / 1745
# Getting coordinates 1143 / 1745
# Getting coordinates 1144 / 1745
# Getting coordinates 1145 / 1745
# Getting coordinates 1146 / 1745
# Getting coordinates 1147 / 1745
# Getting coordinates 1148 / 1745
# Getting coordinates 1149 / 1745
# Getting coordinates 1150 / 1745
# Getting coordinates 1151 / 1745
# Getting coordinates 1152 / 1745
# Getting coordinates 1153 / 1745
# Getting coordinates 1154 / 1745
# Getting coordinates 1155 / 1745
# Getting coordinates 1156 / 1745
# Getting coordinates 1157 / 1745
# Getting coordinates 1158 / 1745
# Getting coordinates 1159 / 1745
# Getting coordinates 1160 / 1745
# Getting coordinates 1161 / 1745
# Getting coordinates 1162 / 1745
# Getting coordinates 1163 / 1745
# Getting coordinates 1164 / 1745
# Getting coordinates 1165 / 1745
# Getting coordinates 1166 / 1745
# Getting coordinates 1167 / 1745
# Getting coordinates 1168 / 1745
# Getting coordinates 1169 / 1745
# Getting coordinates 1170 / 1745
# Getting coordinates 1171 / 1745
# Getting coordinates 1172 / 1745
# Getting coordinates 1173 / 1745
# Getting coordinates 1174 / 1745
# Getting coordinates 1175 / 1745
# Getting coordinates 1176 / 1745
# Getting coordinates 1177 / 1745
# Getting coordinates 1178 / 1745
# Getting coordinates 1179 / 1745
# Getting coordinates 1180 / 1745
# Getting coordinates 1181 / 1745
# Getting coordinates 1182 / 1745
# Getting coordinates 1183 / 1745
# Getting coordinates 1184 / 1745
# Getting coordinates 1185 / 1745
# Getting coordinates 1186 / 1745
# Getting coordinates 1187 / 1745
# Getting coordinates 1188 / 1745
# Getting coordinates 1189 / 1745
# Getting coordinates 1190 / 1745
# Getting coordinates 1191 / 1745
# Getting coordinates 1192 / 1745
# Getting coordinates 1193 / 1745
# Getting coordinates 1194 / 1745
# Getting coordinates 1195 / 1745
# Getting coordinates 1196 / 1745
# Getting coordinates 1197 / 1745
# Getting coordinates 1198 / 1745
# Getting coordinates 1199 / 1745
# Getting coordinates 1200 / 1745
# Getting coordinates 1201 / 1745
# Getting coordinates 1202 / 1745
# Getting coordinates 1203 / 1745
# Getting coordinates 1204 / 1745
# Getting coordinates 1205 / 1745
# Getting coordinates 1206 / 1745
# Getting coordinates 1207 / 1745
# Getting coordinates 1208 / 1745
# Getting coordinates 1209 / 1745
# Getting coordinates 1210 / 1745
# Getting coordinates 1211 / 1745
# Getting coordinates 1212 / 1745
# Getting coordinates 1213 / 1745
# Getting coordinates 1214 / 1745
# Getting coordinates 1215 / 1745
# Getting coordinates 1216 / 1745
# Getting coordinates 1217 / 1745
# Getting coordinates 1218 / 1745
# Getting coordinates 1219 / 1745
# Getting coordinates 1220 / 1745
# Getting coordinates 1221 / 1745
# Getting coordinates 1222 / 1745
# Getting coordinates 1223 / 1745
# Getting coordinates 1224 / 1745
# Getting coordinates 1225 / 1745
# Getting coordinates 1226 / 1745
# Getting coordinates 1227 / 1745
# Getting coordinates 1228 / 1745
# Getting coordinates 1229 / 1745
# Getting coordinates 1230 / 1745
# Getting coordinates 1231 / 1745
# Getting coordinates 1232 / 1745
# Getting coordinates 1233 / 1745
# Getting coordinates 1234 / 1745
# Getting coordinates 1235 / 1745
# Getting coordinates 1236 / 1745
# Getting coordinates 1237 / 1745
# Getting coordinates 1238 / 1745
# Getting coordinates 1239 / 1745
# Getting coordinates 1240 / 1745
# Getting coordinates 1241 / 1745
# Getting coordinates 1242 / 1745
# Getting coordinates 1243 / 1745
# Getting coordinates 1244 / 1745
# Getting coordinates 1245 / 1745
# Getting coordinates 1246 / 1745
# Getting coordinates 1247 / 1745
# Getting coordinates 1248 / 1745
# Getting coordinates 1249 / 1745
# Getting coordinates 1250 / 1745
# Getting coordinates 1251 / 1745
# Getting coordinates 1252 / 1745
# Getting coordinates 1253 / 1745
# Getting coordinates 1254 / 1745
# Getting coordinates 1255 / 1745
# Getting coordinates 1256 / 1745
# Getting coordinates 1257 / 1745
# Getting coordinates 1258 / 1745
# Getting coordinates 1259 / 1745
# Getting coordinates 1260 / 1745
# Getting coordinates 1261 / 1745
# Getting coordinates 1262 / 1745
# Getting coordinates 1263 / 1745
# Getting coordinates 1264 / 1745
# Getting coordinates 1265 / 1745
# Getting coordinates 1266 / 1745
# Getting coordinates 1267 / 1745
# Getting coordinates 1268 / 1745
# Getting coordinates 1269 / 1745
# Getting coordinates 1270 / 1745
# Getting coordinates 1271 / 1745
# Getting coordinates 1272 / 1745
# Getting coordinates 1273 / 1745
# Getting coordinates 1274 / 1745
# Getting coordinates 1275 / 1745
# Getting coordinates 1276 / 1745
# Getting coordinates 1277 / 1745
# Getting coordinates 1278 / 1745
# Getting coordinates 1279 / 1745
# Getting coordinates 1280 / 1745
# Getting coordinates 1281 / 1745
# Getting coordinates 1282 / 1745
# Getting coordinates 1283 / 1745
# Getting coordinates 1284 / 1745
# Getting coordinates 1285 / 1745
# Getting coordinates 1286 / 1745
# Getting coordinates 1287 / 1745
# Getting coordinates 1288 / 1745
# Getting coordinates 1289 / 1745
# Getting coordinates 1290 / 1745
# Getting coordinates 1291 / 1745
# Getting coordinates 1292 / 1745
# Getting coordinates 1293 / 1745
# Getting coordinates 1294 / 1745
# Getting coordinates 1295 / 1745
# Getting coordinates 1296 / 1745
# Getting coordinates 1297 / 1745
# Getting coordinates 1298 / 1745
# Getting coordinates 1299 / 1745
# Getting coordinates 1300 / 1745
# Getting coordinates 1301 / 1745
# Getting coordinates 1302 / 1745
# Getting coordinates 1303 / 1745
# Getting coordinates 1304 / 1745
# Getting coordinates 1305 / 1745
# Getting coordinates 1306 / 1745
# Getting coordinates 1307 / 1745
# Getting coordinates 1308 / 1745
# Getting coordinates 1309 / 1745
# Getting coordinates 1310 / 1745
# Getting coordinates 1311 / 1745
# Getting coordinates 1312 / 1745
# Getting coordinates 1313 / 1745
# Getting coordinates 1314 / 1745
# Getting coordinates 1315 / 1745
# Getting coordinates 1316 / 1745
# Getting coordinates 1317 / 1745
# Getting coordinates 1318 / 1745
# Getting coordinates 1319 / 1745
# Getting coordinates 1320 / 1745
# Getting coordinates 1321 / 1745
# Getting coordinates 1322 / 1745
# Getting coordinates 1323 / 1745
# Getting coordinates 1324 / 1745
# Getting coordinates 1325 / 1745
# Getting coordinates 1326 / 1745
# Getting coordinates 1327 / 1745
# Getting coordinates 1328 / 1745
# Getting coordinates 1329 / 1745
# Getting coordinates 1330 / 1745
# Getting coordinates 1331 / 1745
# Getting coordinates 1332 / 1745
# Getting coordinates 1333 / 1745
# Getting coordinates 1334 / 1745
# Getting coordinates 1335 / 1745
# Getting coordinates 1336 / 1745
# Getting coordinates 1337 / 1745
# Getting coordinates 1338 / 1745
# Getting coordinates 1339 / 1745
# Getting coordinates 1340 / 1745
# Getting coordinates 1341 / 1745
# Getting coordinates 1342 / 1745
# Getting coordinates 1343 / 1745
# Getting coordinates 1344 / 1745
# Getting coordinates 1345 / 1745
# Getting coordinates 1346 / 1745
# Getting coordinates 1347 / 1745
# Getting coordinates 1348 / 1745
# Getting coordinates 1349 / 1745
# Getting coordinates 1350 / 1745
# Getting coordinates 1351 / 1745
# Getting coordinates 1352 / 1745
# Getting coordinates 1353 / 1745
# Getting coordinates 1354 / 1745
# Getting coordinates 1355 / 1745
# Getting coordinates 1356 / 1745
# Getting coordinates 1357 / 1745
# Getting coordinates 1358 / 1745
# Getting coordinates 1359 / 1745
# Getting coordinates 1360 / 1745
# Getting coordinates 1361 / 1745
# Getting coordinates 1362 / 1745
# Getting coordinates 1363 / 1745
# Getting coordinates 1364 / 1745
# Getting coordinates 1365 / 1745
# Getting coordinates 1366 / 1745
# Getting coordinates 1367 / 1745
# Getting coordinates 1368 / 1745
# Getting coordinates 1369 / 1745
# Getting coordinates 1370 / 1745
# Getting coordinates 1371 / 1745
# Getting coordinates 1372 / 1745
# Getting coordinates 1373 / 1745
# Getting coordinates 1374 / 1745
# Getting coordinates 1375 / 1745
# Getting coordinates 1376 / 1745
# Getting coordinates 1377 / 1745
# Getting coordinates 1378 / 1745
# Getting coordinates 1379 / 1745
# Getting coordinates 1380 / 1745
# Getting coordinates 1381 / 1745
# Getting coordinates 1382 / 1745
# Getting coordinates 1383 / 1745
# Getting coordinates 1384 / 1745
# Getting coordinates 1385 / 1745
# Getting coordinates 1386 / 1745
# Getting coordinates 1387 / 1745
# Getting coordinates 1388 / 1745
# Getting coordinates 1389 / 1745
# Getting coordinates 1390 / 1745
# Getting coordinates 1391 / 1745
# Getting coordinates 1392 / 1745
# Getting coordinates 1393 / 1745
# Getting coordinates 1394 / 1745
# Getting coordinates 1395 / 1745
# Getting coordinates 1396 / 1745
# Getting coordinates 1397 / 1745
# Getting coordinates 1398 / 1745
# Getting coordinates 1399 / 1745
# Getting coordinates 1400 / 1745
# Getting coordinates 1401 / 1745
# Getting coordinates 1402 / 1745
# Getting coordinates 1403 / 1745
# Getting coordinates 1404 / 1745
# Getting coordinates 1405 / 1745
# Getting coordinates 1406 / 1745
# Getting coordinates 1407 / 1745
# Getting coordinates 1408 / 1745
# Getting coordinates 1409 / 1745
# Getting coordinates 1410 / 1745
# Getting coordinates 1411 / 1745
# Getting coordinates 1412 / 1745
# Getting coordinates 1413 / 1745
# Getting coordinates 1414 / 1745
# Getting coordinates 1415 / 1745
# Getting coordinates 1416 / 1745
# Getting coordinates 1417 / 1745
# Getting coordinates 1418 / 1745
# Getting coordinates 1419 / 1745
# Getting coordinates 1420 / 1745
# Getting coordinates 1421 / 1745
# Getting coordinates 1422 / 1745
# Getting coordinates 1423 / 1745
# Getting coordinates 1424 / 1745
# Getting coordinates 1425 / 1745
# Getting coordinates 1426 / 1745
# Getting coordinates 1427 / 1745
# Getting coordinates 1428 / 1745
# Getting coordinates 1429 / 1745
# Getting coordinates 1430 / 1745
# Getting coordinates 1431 / 1745
# Getting coordinates 1432 / 1745
# Getting coordinates 1433 / 1745
# Getting coordinates 1434 / 1745
# Getting coordinates 1435 / 1745
# Getting coordinates 1436 / 1745
# Getting coordinates 1437 / 1745
# Getting coordinates 1438 / 1745
# Getting coordinates 1439 / 1745
# Getting coordinates 1440 / 1745
# Getting coordinates 1441 / 1745
# Getting coordinates 1442 / 1745
# Getting coordinates 1443 / 1745
# Getting coordinates 1444 / 1745
# Getting coordinates 1445 / 1745
# Getting coordinates 1446 / 1745
# Getting coordinates 1447 / 1745
# Getting coordinates 1448 / 1745
# Getting coordinates 1449 / 1745
# Getting coordinates 1450 / 1745
# Getting coordinates 1451 / 1745
# Getting coordinates 1452 / 1745
# Getting coordinates 1453 / 1745
# Getting coordinates 1454 / 1745
# Getting coordinates 1455 / 1745
# Getting coordinates 1456 / 1745
# Getting coordinates 1457 / 1745
# Getting coordinates 1458 / 1745
# Getting coordinates 1459 / 1745
# Getting coordinates 1460 / 1745
# Getting coordinates 1461 / 1745
# Getting coordinates 1462 / 1745
# Getting coordinates 1463 / 1745
# Getting coordinates 1464 / 1745
# Getting coordinates 1465 / 1745
# Getting coordinates 1466 / 1745
# Getting coordinates 1467 / 1745
# Getting coordinates 1468 / 1745
# Getting coordinates 1469 / 1745
# Getting coordinates 1470 / 1745
# Getting coordinates 1471 / 1745
# Getting coordinates 1472 / 1745
# Getting coordinates 1473 / 1745
# Getting coordinates 1474 / 1745
# Getting coordinates 1475 / 1745
# Getting coordinates 1476 / 1745
# Getting coordinates 1477 / 1745
# Getting coordinates 1478 / 1745
# Getting coordinates 1479 / 1745
# Getting coordinates 1480 / 1745
# Getting coordinates 1481 / 1745
# Getting coordinates 1482 / 1745
# Getting coordinates 1483 / 1745
# Getting coordinates 1484 / 1745
# Getting coordinates 1485 / 1745
# Getting coordinates 1486 / 1745
# Getting coordinates 1487 / 1745
# Getting coordinates 1488 / 1745
# Getting coordinates 1489 / 1745
# Getting coordinates 1490 / 1745
# Getting coordinates 1491 / 1745
# Getting coordinates 1492 / 1745
# Getting coordinates 1493 / 1745
# Getting coordinates 1494 / 1745
# Getting coordinates 1495 / 1745
# Getting coordinates 1496 / 1745
# Getting coordinates 1497 / 1745
# Getting coordinates 1498 / 1745
# Getting coordinates 1499 / 1745
# Getting coordinates 1500 / 1745
# Getting coordinates 1501 / 1745
# Getting coordinates 1502 / 1745
# Getting coordinates 1503 / 1745
# Getting coordinates 1504 / 1745
# Getting coordinates 1505 / 1745
# Getting coordinates 1506 / 1745
# Getting coordinates 1507 / 1745
# Getting coordinates 1508 / 1745
# Getting coordinates 1509 / 1745
# Getting coordinates 1510 / 1745
# Getting coordinates 1511 / 1745
# Getting coordinates 1512 / 1745
# Getting coordinates 1513 / 1745
# Getting coordinates 1514 / 1745
# Getting coordinates 1515 / 1745
# Getting coordinates 1516 / 1745
# Getting coordinates 1517 / 1745
# Getting coordinates 1518 / 1745
# Getting coordinates 1519 / 1745
# Getting coordinates 1520 / 1745
# Getting coordinates 1521 / 1745
# Getting coordinates 1522 / 1745
# Getting coordinates 1523 / 1745
# Getting coordinates 1524 / 1745
# Getting coordinates 1525 / 1745
# Getting coordinates 1526 / 1745
# Getting coordinates 1527 / 1745
# Getting coordinates 1528 / 1745
# Getting coordinates 1529 / 1745
# Getting coordinates 1530 / 1745
# Getting coordinates 1531 / 1745
# Getting coordinates 1532 / 1745
# Getting coordinates 1533 / 1745
# Getting coordinates 1534 / 1745
# Getting coordinates 1535 / 1745
# Getting coordinates 1536 / 1745
# Getting coordinates 1537 / 1745
# Getting coordinates 1538 / 1745
# Getting coordinates 1539 / 1745
# Getting coordinates 1540 / 1745
# Getting coordinates 1541 / 1745
# Getting coordinates 1542 / 1745
# Getting coordinates 1543 / 1745
# Getting coordinates 1544 / 1745
# Getting coordinates 1545 / 1745
# Getting coordinates 1546 / 1745
# Getting coordinates 1547 / 1745
# Getting coordinates 1548 / 1745
# Getting coordinates 1549 / 1745
# Getting coordinates 1550 / 1745
# Getting coordinates 1551 / 1745
# Getting coordinates 1552 / 1745
# Getting coordinates 1553 / 1745
# Getting coordinates 1554 / 1745
# Getting coordinates 1555 / 1745
# Getting coordinates 1556 / 1745
# Getting coordinates 1557 / 1745
# Getting coordinates 1558 / 1745
# Getting coordinates 1559 / 1745
# Getting coordinates 1560 / 1745
# Getting coordinates 1561 / 1745
# Getting coordinates 1562 / 1745
# Getting coordinates 1563 / 1745
# Getting coordinates 1564 / 1745
# Getting coordinates 1565 / 1745
# Getting coordinates 1566 / 1745
# Getting coordinates 1567 / 1745
# Getting coordinates 1568 / 1745
# Getting coordinates 1569 / 1745
# Getting coordinates 1570 / 1745
# Getting coordinates 1571 / 1745
# Getting coordinates 1572 / 1745
# Getting coordinates 1573 / 1745
# Getting coordinates 1574 / 1745
# Getting coordinates 1575 / 1745
# Getting coordinates 1576 / 1745
# Getting coordinates 1577 / 1745
# Getting coordinates 1578 / 1745
# Getting coordinates 1579 / 1745
# Getting coordinates 1580 / 1745
# Getting coordinates 1581 / 1745
# Getting coordinates 1582 / 1745
# Getting coordinates 1583 / 1745
# Getting coordinates 1584 / 1745
# Getting coordinates 1585 / 1745
# Getting coordinates 1586 / 1745
# Getting coordinates 1587 / 1745
# Getting coordinates 1588 / 1745
# Getting coordinates 1589 / 1745
# Getting coordinates 1590 / 1745
# Getting coordinates 1591 / 1745
# Getting coordinates 1592 / 1745
# Getting coordinates 1593 / 1745
# Getting coordinates 1594 / 1745
# Getting coordinates 1595 / 1745
# Getting coordinates 1596 / 1745
# Getting coordinates 1597 / 1745
# Getting coordinates 1598 / 1745
# Getting coordinates 1599 / 1745
# Getting coordinates 1600 / 1745
# Getting coordinates 1601 / 1745
# Getting coordinates 1602 / 1745
# Getting coordinates 1603 / 1745
# Getting coordinates 1604 / 1745
# Getting coordinates 1605 / 1745
# Getting coordinates 1606 / 1745
# Getting coordinates 1607 / 1745
# Getting coordinates 1608 / 1745
# Getting coordinates 1609 / 1745
# Getting coordinates 1610 / 1745
# Getting coordinates 1611 / 1745
# Getting coordinates 1612 / 1745
# Getting coordinates 1613 / 1745
# Getting coordinates 1614 / 1745
# Getting coordinates 1615 / 1745
# Getting coordinates 1616 / 1745
# Getting coordinates 1617 / 1745
# Getting coordinates 1618 / 1745
# Getting coordinates 1619 / 1745
# Getting coordinates 1620 / 1745
# Getting coordinates 1621 / 1745
# Getting coordinates 1622 / 1745
# Getting coordinates 1623 / 1745
# Getting coordinates 1624 / 1745
# Getting coordinates 1625 / 1745
# Getting coordinates 1626 / 1745
# Getting coordinates 1627 / 1745
# Getting coordinates 1628 / 1745
# Getting coordinates 1629 / 1745
# Getting coordinates 1630 / 1745
# Getting coordinates 1631 / 1745
# Getting coordinates 1632 / 1745
# Getting coordinates 1633 / 1745
# Getting coordinates 1634 / 1745
# Getting coordinates 1635 / 1745
# Getting coordinates 1636 / 1745
# Getting coordinates 1637 / 1745
# Getting coordinates 1638 / 1745
# Getting coordinates 1639 / 1745
# Getting coordinates 1640 / 1745
# Getting coordinates 1641 / 1745
# Getting coordinates 1642 / 1745
# Getting coordinates 1643 / 1745
# Getting coordinates 1644 / 1745
# Getting coordinates 1645 / 1745
# Getting coordinates 1646 / 1745
# Getting coordinates 1647 / 1745
# Getting coordinates 1648 / 1745
# Getting coordinates 1649 / 1745
# Getting coordinates 1650 / 1745
# Getting coordinates 1651 / 1745
# Getting coordinates 1652 / 1745
# Getting coordinates 1653 / 1745
# Getting coordinates 1654 / 1745
# Getting coordinates 1655 / 1745
# Getting coordinates 1656 / 1745
# Getting coordinates 1657 / 1745
# Getting coordinates 1658 / 1745
# Getting coordinates 1659 / 1745
# Getting coordinates 1660 / 1745
# Getting coordinates 1661 / 1745
# Getting coordinates 1662 / 1745
# Getting coordinates 1663 / 1745
# Getting coordinates 1664 / 1745
# Getting coordinates 1665 / 1745
# Getting coordinates 1666 / 1745
# Getting coordinates 1667 / 1745
# Getting coordinates 1668 / 1745
# Getting coordinates 1669 / 1745
# Getting coordinates 1670 / 1745
# Getting coordinates 1671 / 1745
# Getting coordinates 1672 / 1745
# Getting coordinates 1673 / 1745
# Getting coordinates 1674 / 1745
# Getting coordinates 1675 / 1745
# Getting coordinates 1676 / 1745
# Getting coordinates 1677 / 1745
# Getting coordinates 1678 / 1745
# Getting coordinates 1679 / 1745
# Getting coordinates 1680 / 1745
# Getting coordinates 1681 / 1745
# Getting coordinates 1682 / 1745
# Getting coordinates 1683 / 1745
# Getting coordinates 1684 / 1745
# Getting coordinates 1685 / 1745
# Getting coordinates 1686 / 1745
# Getting coordinates 1687 / 1745
# Getting coordinates 1688 / 1745
# Getting coordinates 1689 / 1745
# Getting coordinates 1690 / 1745
# Getting coordinates 1691 / 1745
# Getting coordinates 1692 / 1745
# Getting coordinates 1693 / 1745
# Getting coordinates 1694 / 1745
# Getting coordinates 1695 / 1745
# Getting coordinates 1696 / 1745
# Getting coordinates 1697 / 1745
# Getting coordinates 1698 / 1745
# Getting coordinates 1699 / 1745
# Getting coordinates 1700 / 1745
# Getting coordinates 1701 / 1745
# Getting coordinates 1702 / 1745
# Getting coordinates 1703 / 1745
# Getting coordinates 1704 / 1745
# Getting coordinates 1705 / 1745
# Getting coordinates 1706 / 1745
# Getting coordinates 1707 / 1745
# Getting coordinates 1708 / 1745
# Getting coordinates 1709 / 1745
# Getting coordinates 1710 / 1745
# Getting coordinates 1711 / 1745
# Getting coordinates 1712 / 1745
# Getting coordinates 1713 / 1745
# Getting coordinates 1714 / 1745
# Getting coordinates 1715 / 1745
# Getting coordinates 1716 / 1745
# Getting coordinates 1717 / 1745
# Getting coordinates 1718 / 1745
# Getting coordinates 1719 / 1745
# Getting coordinates 1720 / 1745
# Getting coordinates 1721 / 1745
# Getting coordinates 1722 / 1745
# Getting coordinates 1723 / 1745
# Getting coordinates 1724 / 1745
# Getting coordinates 1725 / 1745
# Getting coordinates 1726 / 1745
# Getting coordinates 1727 / 1745
# Getting coordinates 1728 / 1745
# Getting coordinates 1729 / 1745
# Getting coordinates 1730 / 1745
# Getting coordinates 1731 / 1745
# Getting coordinates 1732 / 1745
# Getting coordinates 1733 / 1745
# Getting coordinates 1734 / 1745
# Getting coordinates 1735 / 1745
# Getting coordinates 1736 / 1745
# Getting coordinates 1737 / 1745
# Getting coordinates 1738 / 1745
# Getting coordinates 1739 / 1745
# Getting coordinates 1740 / 1745
# Getting coordinates 1741 / 1745
# Getting coordinates 1742 / 1745
# Getting coordinates 1743 / 1745
# Getting coordinates 1744 / 1745
# Getting coordinates 1745 / 1745
# Getting people 1 / 1745
# Getting people 2 / 1745
# Getting people 3 / 1745
# Getting people 4 / 1745
# Getting people 5 / 1745
# Getting people 6 / 1745
# Getting people 7 / 1745
# Getting people 8 / 1745
# Getting people 9 / 1745
# Getting people 10 / 1745
# Getting people 11 / 1745
# Getting people 12 / 1745
# Getting people 13 / 1745
# Getting people 14 / 1745
# Getting people 15 / 1745
# Getting people 16 / 1745
# Getting people 17 / 1745
# ...
# Getting Keywords 1195 / 1745
# Getting Keywords 1196 / 1745
# Getting Keywords 1197 / 1745
# Getting Keywords 1198 / 1745
# Getting Keywords 1199 / 1745
# Getting Keywords 1200 / 1745
# Getting Keywords 1201 / 1745
# Getting Keywords 1202 / 1745
# Getting Keywords 1203 / 1745
# Getting Keywords 1204 / 1745
# Getting Keywords 1205 / 1745
# Getting Keywords 1206 / 1745
# Getting Keywords 1207 / 1745
# Getting Keywords 1208 / 1745
# Getting Keywords 1209 / 1745
# Getting Keywords 1210 / 1745
# Getting Keywords 1211 / 1745
# Getting Keywords 1212 / 1745
# Getting Keywords 1213 / 1745
# Getting Keywords 1214 / 1745
# Getting Keywords 1215 / 1745
# Getting Keywords 1216 / 1745
# Getting Keywords 1217 / 1745
# Getting Keywords 1218 / 1745
# Getting Keywords 1219 / 1745
# Getting Keywords 1220 / 1745
# Getting Keywords 1221 / 1745
# Getting Keywords 1222 / 1745
# Getting Keywords 1223 / 1745
# Getting Keywords 1224 / 1745
# Getting Keywords 1225 / 1745
# Getting Keywords 1226 / 1745
# Getting Keywords 1227 / 1745
# Getting Keywords 1228 / 1745
# Getting Keywords 1229 / 1745
# Getting Keywords 1230 / 1745
# Getting Keywords 1231 / 1745
# Getting Keywords 1232 / 1745
# Getting Keywords 1233 / 1745
# Getting Keywords 1234 / 1745
# Getting Keywords 1235 / 1745
# Getting Keywords 1236 / 1745
# Getting Keywords 1237 / 1745
# Getting Keywords 1238 / 1745
# Getting Keywords 1239 / 1745
# Getting Keywords 1240 / 1745
# Getting Keywords 1241 / 1745
# Getting Keywords 1242 / 1745
# Getting Keywords 1243 / 1745
# Getting Keywords 1244 / 1745
# Getting Keywords 1245 / 1745
# Getting Keywords 1246 / 1745
# Getting Keywords 1247 / 1745
# Getting Keywords 1248 / 1745
# Getting Keywords 1249 / 1745
# Getting Keywords 1250 / 1745
# Getting Keywords 1251 / 1745
# Getting Keywords 1252 / 1745
# Getting Keywords 1253 / 1745
# Getting Keywords 1254 / 1745
# Getting Keywords 1255 / 1745
# Getting Keywords 1256 / 1745
# Getting Keywords 1257 / 1745
# Getting Keywords 1258 / 1745
# Getting Keywords 1259 / 1745
# Getting Keywords 1260 / 1745
# Getting Keywords 1261 / 1745
# Getting Keywords 1262 / 1745
# Getting Keywords 1263 / 1745
# Getting Keywords 1264 / 1745
# Getting Keywords 1265 / 1745
# Getting Keywords 1266 / 1745
# Getting Keywords 1267 / 1745
# Getting Keywords 1268 / 1745
# Getting Keywords 1269 / 1745
# Getting Keywords 1270 / 1745
# Getting Keywords 1271 / 1745
# Getting Keywords 1272 / 1745
# Getting Keywords 1273 / 1745
# Getting Keywords 1274 / 1745
# Getting Keywords 1275 / 1745
# Getting Keywords 1276 / 1745
# Getting Keywords 1277 / 1745
# Getting Keywords 1278 / 1745
# Getting Keywords 1279 / 1745
# Getting Keywords 1280 / 1745
# Getting Keywords 1281 / 1745
# Getting Keywords 1282 / 1745
# Getting Keywords 1283 / 1745
# Getting Keywords 1284 / 1745
# Getting Keywords 1285 / 1745
# Getting Keywords 1286 / 1745
# Getting Keywords 1287 / 1745
# Getting Keywords 1288 / 1745
# Getting Keywords 1289 / 1745
# Getting Keywords 1290 / 1745
# Getting Keywords 1291 / 1745
# Getting Keywords 1292 / 1745
# Getting Keywords 1293 / 1745
# Getting Keywords 1294 / 1745
# Getting Keywords 1295 / 1745
# Getting Keywords 1296 / 1745
# Getting Keywords 1297 / 1745
# Getting Keywords 1298 / 1745
# Getting Keywords 1299 / 1745
# Getting Keywords 1300 / 1745
# Getting Keywords 1301 / 1745
# Getting Keywords 1302 / 1745
# Getting Keywords 1303 / 1745
# Getting Keywords 1304 / 1745
# Getting Keywords 1305 / 1745
# Getting Keywords 1306 / 1745
# Getting Keywords 1307 / 1745
# Getting Keywords 1308 / 1745
# Getting Keywords 1309 / 1745
# Getting Keywords 1310 / 1745
# Getting Keywords 1311 / 1745
# Getting Keywords 1312 / 1745
# Getting Keywords 1313 / 1745
# Getting Keywords 1314 / 1745
# Getting Keywords 1315 / 1745
# Getting Keywords 1316 / 1745
# Getting Keywords 1317 / 1745
# Getting Keywords 1318 / 1745
# Getting Keywords 1319 / 1745
# Getting Keywords 1320 / 1745
# Getting Keywords 1321 / 1745
# Getting Keywords 1322 / 1745
# Getting Keywords 1323 / 1745
# Getting Keywords 1324 / 1745
# Getting Keywords 1325 / 1745
# Getting Keywords 1326 / 1745
# Getting Keywords 1327 / 1745
# Getting Keywords 1328 / 1745
# Getting Keywords 1329 / 1745
# Getting Keywords 1330 / 1745
# Getting Keywords 1331 / 1745
# Getting Keywords 1332 / 1745
# Getting Keywords 1333 / 1745
# Getting Keywords 1334 / 1745
# Getting Keywords 1335 / 1745
# Getting Keywords 1336 / 1745
# Getting Keywords 1337 / 1745
# Getting Keywords 1338 / 1745
# Getting Keywords 1339 / 1745
# Getting Keywords 1340 / 1745
# Getting Keywords 1341 / 1745
# Getting Keywords 1342 / 1745
# Getting Keywords 1343 / 1745
# Getting Keywords 1344 / 1745
# Getting Keywords 1345 / 1745
# Getting Keywords 1346 / 1745
# Getting Keywords 1347 / 1745
# Getting Keywords 1348 / 1745
# Getting Keywords 1349 / 1745
# Getting Keywords 1350 / 1745
# Getting Keywords 1351 / 1745
# Getting Keywords 1352 / 1745
# Getting Keywords 1353 / 1745
# Getting Keywords 1354 / 1745
# Getting Keywords 1355 / 1745
# Getting Keywords 1356 / 1745
# Getting Keywords 1357 / 1745
# Getting Keywords 1358 / 1745
# Getting Keywords 1359 / 1745
# Getting Keywords 1360 / 1745
# Getting Keywords 1361 / 1745
# Getting Keywords 1362 / 1745
# Getting Keywords 1363 / 1745
# Getting Keywords 1364 / 1745
# Getting Keywords 1365 / 1745
# Getting Keywords 1366 / 1745
# Getting Keywords 1367 / 1745
# Getting Keywords 1368 / 1745
# Getting Keywords 1369 / 1745
# Getting Keywords 1370 / 1745
# Getting Keywords 1371 / 1745
# Getting Keywords 1372 / 1745
# Getting Keywords 1373 / 1745
# Getting Keywords 1374 / 1745
# Getting Keywords 1375 / 1745
# Getting Keywords 1376 / 1745
# Getting Keywords 1377 / 1745
# Getting Keywords 1378 / 1745
# Getting Keywords 1379 / 1745
# Getting Keywords 1380 / 1745
# Getting Keywords 1381 / 1745
# Getting Keywords 1382 / 1745
# Getting Keywords 1383 / 1745
# Getting Keywords 1384 / 1745
# Getting Keywords 1385 / 1745
# Getting Keywords 1386 / 1745
# Getting Keywords 1387 / 1745
# Getting Keywords 1388 / 1745
# Getting Keywords 1389 / 1745
# Getting Keywords 1390 / 1745
# Getting Keywords 1391 / 1745
# Getting Keywords 1392 / 1745
# Getting Keywords 1393 / 1745
# Getting Keywords 1394 / 1745
# Getting Keywords 1395 / 1745
# Getting Keywords 1396 / 1745
# Getting Keywords 1397 / 1745
# Getting Keywords 1398 / 1745
# Getting Keywords 1399 / 1745
# Getting Keywords 1400 / 1745
# Getting Keywords 1401 / 1745
# Getting Keywords 1402 / 1745
# Getting Keywords 1403 / 1745
# Getting Keywords 1404 / 1745
# Getting Keywords 1405 / 1745
# Getting Keywords 1406 / 1745
# Getting Keywords 1407 / 1745
# Getting Keywords 1408 / 1745
# Getting Keywords 1409 / 1745
# Getting Keywords 1410 / 1745
# Getting Keywords 1411 / 1745
# Getting Keywords 1412 / 1745
# Getting Keywords 1413 / 1745
# Getting Keywords 1414 / 1745
# Getting Keywords 1415 / 1745
# Getting Keywords 1416 / 1745
# Getting Keywords 1417 / 1745
# Getting Keywords 1418 / 1745
# Getting Keywords 1419 / 1745
# Getting Keywords 1420 / 1745
# Getting Keywords 1421 / 1745
# Getting Keywords 1422 / 1745
# Getting Keywords 1423 / 1745
# Getting Keywords 1424 / 1745
# Getting Keywords 1425 / 1745
# Getting Keywords 1426 / 1745
# Getting Keywords 1427 / 1745
# Getting Keywords 1428 / 1745
# Getting Keywords 1429 / 1745
# Getting Keywords 1430 / 1745
# Getting Keywords 1431 / 1745
# Getting Keywords 1432 / 1745
# Getting Keywords 1433 / 1745
# Getting Keywords 1434 / 1745
# Getting Keywords 1435 / 1745
# Getting Keywords 1436 / 1745
# Getting Keywords 1437 / 1745
# Getting Keywords 1438 / 1745
# Getting Keywords 1439 / 1745
# Getting Keywords 1440 / 1745
# Getting Keywords 1441 / 1745
# Getting Keywords 1442 / 1745
# Getting Keywords 1443 / 1745
# Getting Keywords 1444 / 1745
# Getting Keywords 1445 / 1745
# Getting Keywords 1446 / 1745
# Getting Keywords 1447 / 1745
# Getting Keywords 1448 / 1745
# Getting Keywords 1449 / 1745
# Getting Keywords 1450 / 1745
# Getting Keywords 1451 / 1745
# Getting Keywords 1452 / 1745
# Getting Keywords 1453 / 1745
# Getting Keywords 1454 / 1745
# Getting Keywords 1455 / 1745
# Getting Keywords 1456 / 1745
# Getting Keywords 1457 / 1745
# Getting Keywords 1458 / 1745
# Getting Keywords 1459 / 1745
# Getting Keywords 1460 / 1745
# Getting Keywords 1461 / 1745
# Getting Keywords 1462 / 1745
# Getting Keywords 1463 / 1745
# Getting Keywords 1464 / 1745
# Getting Keywords 1465 / 1745
# Getting Keywords 1466 / 1745
# Getting Keywords 1467 / 1745
# Getting Keywords 1468 / 1745
# Getting Keywords 1469 / 1745
# Getting Keywords 1470 / 1745
# Getting Keywords 1471 / 1745
# Getting Keywords 1472 / 1745
# Getting Keywords 1473 / 1745
# Getting Keywords 1474 / 1745
# Getting Keywords 1475 / 1745
# Getting Keywords 1476 / 1745
# Getting Keywords 1477 / 1745
# Getting Keywords 1478 / 1745
# Getting Keywords 1479 / 1745
# Getting Keywords 1480 / 1745
# Getting Keywords 1481 / 1745
# Getting Keywords 1482 / 1745
# Getting Keywords 1483 / 1745
# Getting Keywords 1484 / 1745
# Getting Keywords 1485 / 1745
# Getting Keywords 1486 / 1745
# Getting Keywords 1487 / 1745
# Getting Keywords 1488 / 1745
# Getting Keywords 1489 / 1745
# Getting Keywords 1490 / 1745
# Getting Keywords 1491 / 1745
# Getting Keywords 1492 / 1745
# Getting Keywords 1493 / 1745
# Getting Keywords 1494 / 1745
# Getting Keywords 1495 / 1745
# Getting Keywords 1496 / 1745
# Getting Keywords 1497 / 1745
# Getting Keywords 1498 / 1745
# Getting Keywords 1499 / 1745
# Getting Keywords 1500 / 1745
# Getting Keywords 1501 / 1745
# Getting Keywords 1502 / 1745
# Getting Keywords 1503 / 1745
# Getting Keywords 1504 / 1745
# Getting Keywords 1505 / 1745
# Getting Keywords 1506 / 1745
# Getting Keywords 1507 / 1745
# Getting Keywords 1508 / 1745
# Getting Keywords 1509 / 1745
# Getting Keywords 1510 / 1745
# Getting Keywords 1511 / 1745
# Getting Keywords 1512 / 1745
# Getting Keywords 1513 / 1745
# Getting Keywords 1514 / 1745
# Getting Keywords 1515 / 1745
# Getting Keywords 1516 / 1745
# Getting Keywords 1517 / 1745
# Getting Keywords 1518 / 1745
# Getting Keywords 1519 / 1745
# Getting Keywords 1520 / 1745
# Getting Keywords 1521 / 1745
# Getting Keywords 1522 / 1745
# Getting Keywords 1523 / 1745
# Getting Keywords 1524 / 1745
# Getting Keywords 1525 / 1745
# Getting Keywords 1526 / 1745
# Getting Keywords 1527 / 1745
# Getting Keywords 1528 / 1745
# Getting Keywords 1529 / 1745
# Getting Keywords 1530 / 1745
# Getting Keywords 1531 / 1745
# Getting Keywords 1532 / 1745
# Getting Keywords 1533 / 1745
# Getting Keywords 1534 / 1745
# Getting Keywords 1535 / 1745
# Getting Keywords 1536 / 1745
# Getting Keywords 1537 / 1745
# Getting Keywords 1538 / 1745
# Getting Keywords 1539 / 1745
# Getting Keywords 1540 / 1745
# Getting Keywords 1541 / 1745
# Getting Keywords 1542 / 1745
# Getting Keywords 1543 / 1745
# Getting Keywords 1544 / 1745
# Getting Keywords 1545 / 1745
# Getting Keywords 1546 / 1745
# Getting Keywords 1547 / 1745
# Getting Keywords 1548 / 1745
# Getting Keywords 1549 / 1745
# Getting Keywords 1550 / 1745
# Getting Keywords 1551 / 1745
# Getting Keywords 1552 / 1745
# Getting Keywords 1553 / 1745
# Getting Keywords 1554 / 1745
# Getting Keywords 1555 / 1745
# Getting Keywords 1556 / 1745
# Getting Keywords 1557 / 1745
# Getting Keywords 1558 / 1745
# Getting Keywords 1559 / 1745
# Getting Keywords 1560 / 1745
# Getting Keywords 1561 / 1745
# Getting Keywords 1562 / 1745
# Getting Keywords 1563 / 1745
# Getting Keywords 1564 / 1745
# Getting Keywords 1565 / 1745
# Getting Keywords 1566 / 1745
# Getting Keywords 1567 / 1745
# Getting Keywords 1568 / 1745
# Getting Keywords 1569 / 1745
# Getting Keywords 1570 / 1745
# Getting Keywords 1571 / 1745
# Getting Keywords 1572 / 1745
# Getting Keywords 1573 / 1745
# Getting Keywords 1574 / 1745
# Getting Keywords 1575 / 1745
# Getting Keywords 1576 / 1745
# Getting Keywords 1577 / 1745
# Getting Keywords 1578 / 1745
# Getting Keywords 1579 / 1745
# Getting Keywords 1580 / 1745
# Getting Keywords 1581 / 1745
# Getting Keywords 1582 / 1745
# Getting Keywords 1583 / 1745
# Getting Keywords 1584 / 1745
# Getting Keywords 1585 / 1745
# Getting Keywords 1586 / 1745
# Getting Keywords 1587 / 1745
# Getting Keywords 1588 / 1745
# Getting Keywords 1589 / 1745
# Getting Keywords 1590 / 1745
# Getting Keywords 1591 / 1745
# Getting Keywords 1592 / 1745
# Getting Keywords 1593 / 1745
# Getting Keywords 1594 / 1745
# Getting Keywords 1595 / 1745
# Getting Keywords 1596 / 1745
# Getting Keywords 1597 / 1745
# Getting Keywords 1598 / 1745
# Getting Keywords 1599 / 1745
# Getting Keywords 1600 / 1745
# Getting Keywords 1601 / 1745
# Getting Keywords 1602 / 1745
# Getting Keywords 1603 / 1745
# Getting Keywords 1604 / 1745
# Getting Keywords 1605 / 1745
# Getting Keywords 1606 / 1745
# Getting Keywords 1607 / 1745
# Getting Keywords 1608 / 1745
# Getting Keywords 1609 / 1745
# Getting Keywords 1610 / 1745
# Getting Keywords 1611 / 1745
# Getting Keywords 1612 / 1745
# Getting Keywords 1613 / 1745
# Getting Keywords 1614 / 1745
# Getting Keywords 1615 / 1745
# Getting Keywords 1616 / 1745
# Getting Keywords 1617 / 1745
# Getting Keywords 1618 / 1745
# Getting Keywords 1619 / 1745
# Getting Keywords 1620 / 1745
# Getting Keywords 1621 / 1745
# Getting Keywords 1622 / 1745
# Getting Keywords 1623 / 1745
# Getting Keywords 1624 / 1745
# Getting Keywords 1625 / 1745
# Getting Keywords 1626 / 1745
# Getting Keywords 1627 / 1745
# Getting Keywords 1628 / 1745
# Getting Keywords 1629 / 1745
# Getting Keywords 1630 / 1745
# Getting Keywords 1631 / 1745
# Getting Keywords 1632 / 1745
# Getting Keywords 1633 / 1745
# Getting Keywords 1634 / 1745
# Getting Keywords 1635 / 1745
# Getting Keywords 1636 / 1745
# Getting Keywords 1637 / 1745
# Getting Keywords 1638 / 1745
# Getting Keywords 1639 / 1745
# Getting Keywords 1640 / 1745
# Getting Keywords 1641 / 1745
# Getting Keywords 1642 / 1745
# Getting Keywords 1643 / 1745
# Getting Keywords 1644 / 1745
# Getting Keywords 1645 / 1745
# Getting Keywords 1646 / 1745
# Getting Keywords 1647 / 1745
# Getting Keywords 1648 / 1745
# Getting Keywords 1649 / 1745
# Getting Keywords 1650 / 1745
# Getting Keywords 1651 / 1745
# Getting Keywords 1652 / 1745
# Getting Keywords 1653 / 1745
# Getting Keywords 1654 / 1745
# Getting Keywords 1655 / 1745
# Getting Keywords 1656 / 1745
# Getting Keywords 1657 / 1745
# Getting Keywords 1658 / 1745
# Getting Keywords 1659 / 1745
# Getting Keywords 1660 / 1745
# Getting Keywords 1661 / 1745
# Getting Keywords 1662 / 1745
# Getting Keywords 1663 / 1745
# Getting Keywords 1664 / 1745
# Getting Keywords 1665 / 1745
# Getting Keywords 1666 / 1745
# Getting Keywords 1667 / 1745
# Getting Keywords 1668 / 1745
# Getting Keywords 1669 / 1745
# Getting Keywords 1670 / 1745
# Getting Keywords 1671 / 1745
# Getting Keywords 1672 / 1745
# Getting Keywords 1673 / 1745
# Getting Keywords 1674 / 1745
# Getting Keywords 1675 / 1745
# Getting Keywords 1676 / 1745
# Getting Keywords 1677 / 1745
# Getting Keywords 1678 / 1745
# Getting Keywords 1679 / 1745
# Getting Keywords 1680 / 1745
# Getting Keywords 1681 / 1745
# Getting Keywords 1682 / 1745
# Getting Keywords 1683 / 1745
# Getting Keywords 1684 / 1745
# Getting Keywords 1685 / 1745
# Getting Keywords 1686 / 1745
# Getting Keywords 1687 / 1745
# Getting Keywords 1688 / 1745
# Getting Keywords 1689 / 1745
# Getting Keywords 1690 / 1745
# Getting Keywords 1691 / 1745
# Getting Keywords 1692 / 1745
# Getting Keywords 1693 / 1745
# Getting Keywords 1694 / 1745
# Getting Keywords 1695 / 1745
# Getting Keywords 1696 / 1745
# Getting Keywords 1697 / 1745
# Getting Keywords 1698 / 1745
# Getting Keywords 1699 / 1745
# Getting Keywords 1700 / 1745
# Getting Keywords 1701 / 1745
# Getting Keywords 1702 / 1745
# Getting Keywords 1703 / 1745
# Getting Keywords 1704 / 1745
# Getting Keywords 1705 / 1745
# Getting Keywords 1706 / 1745
# Getting Keywords 1707 / 1745
# Getting Keywords 1708 / 1745
# Getting Keywords 1709 / 1745
# Getting Keywords 1710 / 1745
# Getting Keywords 1711 / 1745
# Getting Keywords 1712 / 1745
# Getting Keywords 1713 / 1745
# Getting Keywords 1714 / 1745
# Getting Keywords 1715 / 1745
# Getting Keywords 1716 / 1745
# Getting Keywords 1717 / 1745
# Getting Keywords 1718 / 1745
# Getting Keywords 1719 / 1745
# Getting Keywords 1720 / 1745
# Getting Keywords 1721 / 1745
# Getting Keywords 1722 / 1745
# Getting Keywords 1723 / 1745
# Getting Keywords 1724 / 1745
# Getting Keywords 1725 / 1745
# Getting Keywords 1726 / 1745
# Getting Keywords 1727 / 1745
# Getting Keywords 1728 / 1745
# Getting Keywords 1729 / 1745
# Getting Keywords 1730 / 1745
# Getting Keywords 1731 / 1745
# Getting Keywords 1732 / 1745
# Getting Keywords 1733 / 1745
# Getting Keywords 1734 / 1745
# Getting Keywords 1735 / 1745
# Getting Keywords 1736 / 1745
# Getting Keywords 1737 / 1745
# Getting Keywords 1738 / 1745
# Getting Keywords 1739 / 1745
# Getting Keywords 1740 / 1745
# Getting Keywords 1741 / 1745
# Getting Keywords 1742 / 1745
# Getting Keywords 1743 / 1745
# Getting Keywords 1744 / 1745
# Getting Keywords 1745 / 1745

# %% [markdown]
# ##Topic Modeling Enrichment
#
# Our next problem is this: Our clusters gave us a list of words that are associated with each cluster, but the clusters are titled simply with numbers. This gives us the opportunity to plot a word cloud or other interesting visualization that can help us understand each cluster, but it not as useful for *at-a-glance* understanding in a structured dataset. Additionally, I believe that some documents may fall within multiple topic categories. Multiple clustering is not supported by k-means, so I will have to identify these documents manually. First, I'll print the first few rows of keywords to get an idea of the data I'm dealing with.

# %%
cluster_keywords[:5]
# Out:
# ['ret,islamic,political,province,military,groups,security,us,state,states,syrian,diyala,american,isis,nov,isw,qaeda,al,syria,iraq',
#  'ar,raqqa,eastern,northern,al,campaign,city,province,update,forces,iraq,may,syrian,ez,zour,regime,deir,sdf,syria,isis',
#  'haq,ahl,ib,gains,asa,january,activity,deir,control,ez,zour,isis,iraq,november,update,report,situation,syria,dec,december',
#  'eu,political,president,bugayova,intsum,sanctions,nataliya,nato,west,elections,review,africa,information,military,ukrainian,russian,putin,ukraine,kremlin,russia',
#  'damascus,isis,jabhat,military,homs,russian,province,pro,russia,groups,forces,rebel,al,city,assad,opposition,syria,aleppo,syrian,regime']

# %% [markdown]
# ##Topic Modeling Enrichment (cont.)
#
# After significant experimentation with a variety of techniques, I decided on a very simple approach. I scanned each list of keywords pertaining to each cluster, and noted significant keywords in each that related to a specific topic. At this stage, **domain knowledge** was key. I know, for example, that **Aleppo** in an ISW document is almost certainly mentioned in reference to the **Syrian Civil War**. For your data, if you lack the appropriate domain knowledge, you may need to do further research, consult someone else on your team, or define a more advanced programmatic method for titling your clusters.
#
# For this example, however, the simple approach works well. After making note of several significant keywords present in the cluster lists, I made a few lists of my own that contained keywords associated to the final topic categories I wanted in the structured data. The function simply compares each cluster's list of keywords with the lists I created, then assigned a topic name based on matches in the lists. It then appends those final topics to a list of **topic_categories**.

# %%
#Searches lists of keywords corresponding to topic, 
#cross-references with cluster word banks to assign a topic category to each article. 

oir=['OIR Iraq','yezidis','mosul','peshmerga','isis','iraq','sinjar','baghdad','maliki',
     'daquq','anbar','isf','abadi','malaki','ramadi','iraqi','fallujah','dabiq']

terrorism=['Terrorism','jihadi','islamic','salafi','qaeda',
           'caliphate','isis','terrorist','terrorism']

syrian_conflict=['Syrian Conflict','sana','syria','assad',
                 'idlib','afrin','aleppo']

russia=['Russia','russia','belarus','slavic','kremlin','russian',
        'minsk','ukraine','putin']

iran=['Iran','iran','iranian','proxy','militias','militia','marjah']

turkey=['Turkey','erdogan','turkish','turkey']

ors=['ORS','kabul','ghani','pakistan','afghan','afghanistan',
     'taliban','ansf','karzai','helmand']

africa=['Africa','libya','libyan','egypt','egyptian','africa','african']

cat_list=[oir,terrorism,syrian_conflict,russia,iran,turkey,ors,africa]

topic_dict={}

for i in range(len(cluster_keywords)):
  temp_list=[]
  for n in nltk.word_tokenize(cluster_keywords[i]):
    for item in cat_list:
      if n in item:
        temp_list.append(item[0])
  
  temp_dict=dict.fromkeys(temp_list,0)
  temp_list=list(temp_dict)

  topic_dict[i] = temp_list

for num in cluster_number:
  topic_categories.append(topic_dict[num])

# %% [markdown]
# #Database Creation
#
# The very last step in this guide is to bring together all our extracted data. For this data, I prefer the **JSON** format. This is because I wanted to structure certain types of data differently - for example, the **locations** field will include a **list of dictionaries** of place names, latitudes, and longitudes. In my opinion, JSON format is the most effective way to store such formatted data to a local disk. I also backed up a copy of this database in a document database, **MongoDB**, but that is not the focus of this guide. If you are interested in saving your structured data to a document database, try [this article on Medium](https://medium.com/free-code-camp/learn-mongodb-a4ce205e7739).

# %%
#Initalize an empty list for storage

db=[]

for i in range(len(hrefs)):
  countries={
      'focus area': key_countries[i],
      'all mentioned countries': mentioned_countries[i]
  }

  #Add all of the defined lists from our functions
  #To the new storage list

  doc={ 
      '_id': len(hrefs) - i,
       'title': titles[i],
       'date': dates[i],
       'places': coord_list[i],
       'people': people[i],
       'keywords': keywords[i],
       'countries': countries,
       'full text': content_text[i],
       'url': links[i],
       'topic cluster': cluster_number[i],
       'categories': topic_categories[i]
  }

  db.append(doc)

#Save the list as a .JSON data storage file inside google drive
#(for demonstration purposes)

with open ('/content/drive/My Drive/Colab Notebooks/isw_products.json', 'w') as fout:
  json.dump(db, fout)

# %% [markdown]
# #Summary
#
# Now we're done! We covered a lot in this guide. We extracted links from a web page, then used those links to extract even more content from the web site. We used that content to then extract and enhance that informaion using **external APIs**, ML **clustering algorithms**, and **NLP**. NLP today is one of the foremost buzz-words in the business intelligence community, and now upon completion of this guide you can confidently execute intermediate-level operations in NLP for document analysis. You can conduct **TF-IDF vectorization**, **keyword extraction**, and **topic modeling**. These are the cornerstones of NLP. Please [reach out](https://www.linkedin.com/in/cmbrew/) if you have more questions or need information, and good luck in your future NLP endeavors!

# %%
with open (r'/content/drive/My Drive/Colab Notebooks/isw_products.json','r') as read_file:
  data=json.load(read_file)

data[0:5]
# Out:
# [{'_id': 1745,
#   'categories': ['Russia'],
#   'countries': {'all mentioned countries': ['Russia',
#     'Belarus',
#     'Azerbaijan',
#     'Kyrgyzstan',
#     'Serbia'],
#    'focus area': ['Russia', 'Belarus']},
#   'date': '2020-10-20T15:07:13-04:00',
#   'full text': 'Russia’s Unprecedentedly Expansive Military Exercises in Fall 2020 Seek to Recreate Soviet-Style Multinational Army | Institute for the Study of War Search form Russia’s Unprecedentedly Expansive Military Exercises in Fall 2020 Seek to Recreate Soviet-Style Multinational Army Oct 20, 2020 - George Barros, Mason Clark October 20, 2020 By Mason Clark and George Barros Key Takeaway: The Kremlin has conducted military exercises in fall 2020 on an unprecedented scale, much deeper than usual integration of Russian and foreign military units, and a pattern of modifying pre-announced activities significantly but presenting them as normal and unchanged. These exercises mark significant developments in the Kremlin’s campaigns to integrate the security forces of Former Soviet Union (FSU) states into Russian-dominated structures. Russian forces conducted simultaneous exercises on a scale nearly equivalent to that of two normal annual capstone exercises, suggesting that Russian forces may be able to mobilize and control more combat units and at higher echelons than had previously been assessed. The Kremlin covered new deployments to Belarus by branding them as “preplanned exercises” to create a false sense of normality. The Kremlin will likely exploit this kind of rebranding as an instrument of its hybrid warfare toolkit to cover actual combat deployments abroad. Moscow also announced that it would intensify efforts to gain United Nations recognition of the revivified multinational military it is trying to create in the FSU as a legitimate peacekeeping force. There are several concrete steps the United States and NATO should take to mitigate these new threats. The Kremlin conducted military exercises in Fall 2020 on an unprecedented scale to advance efforts to recreate a multinational armed forces of the former Soviet states for which it seeks UN approval as a legitimate peacekeeping force. It concealed the significance of these exercises by casting them as pre-announced and pre-planned despite making major changes immediately before their execution.\xa0\xa0 Russian forces in the Western and Southern Military Districts conducted unprecedented simultaneous exercises near the scale of two normal annual capstone readiness exercises in September.\xa0 Russian Western Military District (WMD) forces exercised in both Belarus and the WMD on September 15-28 on a larger scale than they did during the last annual capstone exercise in the WMD in 2017. \xa0Kavkaz-2020, this year’s iteration of Russia’s annual capstone military readiness exercises in the Southern Military District on September 21-26, should have precipitated a decrease in WMD activity but did not. Click here to expand the map\xa0below. These unprecedented exercises seek to subordinate FSU militaries to the Kremlin to recreate a multinational army in the former Soviet space.\xa0 The Kremlin created a combined Russian-Belarusian combat battalion for the first time during the Slavic Brotherhood exercises from September 14-25. \xa0The Kremlin has previously used joint exercises with Belarus—most notably Union Shield 2019—to integrate Belarusian forces into Kremlin-run structures, but has not created joint combat units dynamically during an exercise prior to September 2020. \xa0A successful Kremlin effort to institutionalize joint units in Belarus or elsewhere would magnify the Kremlin’s power projection capabilities and enable the Kremlin to exert direct control over elements of FSU militaries in the event of Russian deployments. Success in this effort might give Moscow the ability to subvert parts of the units of those militaries even against the orders of their governments, although it is impossible to assess that risk with any confidence. The Kremlin used Kavkaz-2020 to increase interoperability between Russian, Belarusian, Armenian, Kremlin proxy republic, Chinese, Iranian, Pakistani, and Myanma units. \xa0The Kremlin deployed personnel from both the CSTO’s secretariat a ...
#   'keywords': ['exercises',
#    'kremlin',
#    'russian',
#    'fsu',
#    'brotherhood',
#    'deployments',
#    'belarus',
#    'dot',
#    'unbreakable',
#    'wmd'],
#   'people': ['Vladimir Putin'],
#   'places': [{'Lat': 64.6863136, 'Location': 'Russia', 'Lon': 97.7453061},
#    {'Lat': 55.7514952, 'Location': 'Kremlin', 'Lon': 37.6181531},
#    {'Lat': 55.4805995, 'Location': 'Soviet Union', 'Lon': 28.773013},
#    {'Lat': 53.4250605, 'Location': 'Belarus', 'Lon': 27.6971358},
#    {'Lat': 55.7504461, 'Location': 'Moscow', 'Lon': 37.6174943},
#    {'Lat': 40.3936294, 'Location': 'Azerbaijan', 'Lon': 47.7872508},
#    {'Lat': 41.5089324, 'Location': 'Kyrgyzstan', 'Lon': 74.724091},
#    {'Lat': 44.0243229, 'Location': 'Serbia', 'Lon': 21.0765743},
#    {'Lat': 52.2809939, 'Location': 'bratstvo-2020', 'Lon': 43.6981349}],
#   'title': 'Russia’s Unprecedentedly Expansive Military Exercises in Fall 2020 Seek to Recreate Soviet-Style Multinational Army',
#   'topic cluster': 47,
#   'url': 'http://www.understandingwar.org/backgrounder/russia%E2%80%99s-unprecedentedly-expansive-military-exercises-fall-2020-seek-recreate-soviet'},
#  {'_id': 1744,
#   'categories': ['Russia'],
#   'countries': {'all mentioned countries': ['Belarus'],
#    'focus area': ['Belarus']},
#   'date': '2020-10-19T19:03:40-04:00',
#   'full text': 'Belarus Warning Update: Lukashenko Attempts to De-escalate Protests Ahead of October 25 Opposition Ultimatum | Institute for the Study of War Search form Belarus Warning Update: Lukashenko Attempts to De-escalate Protests Ahead of October 25 Opposition Ultimatum Oct 19, 2020 - George Barros October 19, 2020, 7:00 pm EDT By George Barros Self-declared Belarusian president Alexander Lukashenko is intensifying efforts to de-escalate protests and degrade protester will in the runup to October 25.\xa0 Lukashenko set October 25 as the deadline for submissions “from the people” of Belarusian constitutional amendments on October 3. He likely seeks to use this amendment process to broker a pretend compromise with protesters to end the crisis without actually ceding power. Lithuania-based Belarusian opposition leader Svitlana Tikhanouskaya likely saw the danger that this ploy would succeed and countered by demanding on October 13 that Lukashenko resign by October 25. \xa0Tikahnouskaya is thus setting the stage for large-scale anti-Lukashenko protests to upstage his announcement of the next phase of his efforts to create an off-ramp from the protest movement. Lukashenko is relaxing his protester suppression and detention campaigns after having increased their brutality last weekend, likely to set more positive conditions for whatever announcement he plans to make on October 25. \xa0Belarusian security forces’ response to weekend protests were not as intense as those that occurred the week of October 11. \xa0Belarusian authorities detained 215 protesters on October 18—half as many detentions as on October 11. Lukashenko is also intensifying efforts to conduct pro-regime rallies rather than focusing only on suppressing anti-regime rallies as he has largely done for the past several weeks. \xa0Lukashenko reportedly planned multiple unspecified pro-government rallies in Minsk for the week of October 18-25. \xa0These rallies are likely meant to offset the negativity of the anti-government protests and create the basis for a narrative of popular support for whatever changes he offers. Lukashenko freed seven jailed opposition leaders after meeting with some of them on October 10. \xa0Lukashenko freed seven Belarusian opposition leaders, including Maria Kolesnikova’s lawyer and Coordination Council member Lilia Vlasova, between October 14-16. \xa0News of the releases did not surface until October 19. Lukashenko continues to hold prisoner senior opposition leaders Viktar Babariko, Maria Kolesnikova, and Sergei\xa0Tikhanousky –Tikhanouskaya’s husband – as leverage as of this writing. Lukashenko likely released the seven opposition leaders to appear willing to engage in dialogue and concede to limited protester demands.\xa0Lukashenko will likely leverage his current detainees as hostages to deter protest escalation. Lukashenko continues to successfully reduce the size of the weekend protests. \xa0Saturday protests in Minsk continued to be small with only 100 women and 150 students participating in protests on October 17. \xa0Approximately 50,000 protesters—which was the smallest size of Sunday protests since protests began in August—participated in the October 18 march. \xa0Saturday protests have steadily declined in size since early September. ISW previously forecasted that weekend protests would decline in size – and may increasingly only occur on Sundays—due to successful pressure by Lukashenko, a lack of emerging local leadership in Belarus, and worsening weather. \xa0Belarusian authorities’ October 12 threat to use lethal force to suppress protests “if necessary” likely also deterred some Belarusians from protesting on October 17-18. Weekday protests are growing, but Lukashenko met them with pro-government protests rather than violence this week.\xa0 Approximately 5,000 pensioners—significantly larger numbers than in this protest’s past two iterations—marched in Minsk on October 19. \xa0Belarusian authorities cracked down harsh ...
#   'keywords': ['lukashenko',
#    'dot',
#    'october',
#    'protests',
#    'belarusian',
#    'pensioners',
#    'rallies',
#    'weekend',
#    'html',
#    'ru'],
#   'people': ['Alexander Lukashenko', 'Maria Kolesnikova', 'Lilia Vlasova'],
#   'places': [{'Lat': 53.4250605, 'Location': 'Belarus', 'Lon': 27.6971358},
#    {'Lat': 53.902334, 'Location': 'Minsk', 'Lon': 27.5618791}],
#   'title': 'Belarus Warning Update: Lukashenko Attempts to De-escalate Protests Ahead of October 25 Opposition Ultimatum',
#   'topic cluster': 47,
#   'url': 'http://www.understandingwar.org/backgrounder/belarus-warning-update-lukashenko-attempts-de-escalate-protests-ahead-october-25'},
#  {'_id': 1743,
#   'categories': ['Russia', 'Syrian Conflict', 'Turkey'],
#   'countries': {'all mentioned countries': ['Russia',
#     'Syria',
#     'Turkey',
#     'Libya'],
#    'focus area': ['Russia', 'Syria', 'Turkey']},
#   'date': '2020-10-17T12:15:02-04:00',
#   'full text': 'Russia May Deploy Conventional Forces to Syria | Institute for the Study of War Search form Russia May Deploy Conventional Forces to Syria Oct 17, 2020 - Isabel Ivanescu By Isabel Ivanescu October 17, 2020 Key Takeaway: \xa0Russia may deploy conventional ground forces to Syria to gain leverage in negotiations with Turkey and possibly participate in a pro-Assad regime offensive. Russia and Turkey are pressing one another for concessions in negotiations concerning opposition-held Idlib Province. A Russian conventional military deployment remains unlikely, but various indicators have tripped in the past few weeks suggesting that Moscow could be preparing for one. Such a deployment would mark an inflection in Russia’s participation in Syria and an escalation in the conflict between Russia and Turkey. Turkey and Russia are seeking leverage to set favorable conditions for a new round of negotiations about the fate of Idlib Province, as stalemate there persists.\xa0 Russia-Turkey negotiations on Idlib on September 16, 2020, did not result in a settlement. \xa0Turkey has subsequently reinforced its military positions in the province as Russia and the Assad regime have escalated airstrikes, shelling, and infiltration attempts. \xa0Russia likely seeks a Turkish withdrawal from parts of southern Idlib to enable a pro-Assad regime offensive against Salafi-jihadist opposition forces without Turkish intervention. Turkey likely seeks concessions in other theaters of Russia-Turkey competition such as northeastern Syria, Libya, and the Caucasus.\xa0 Turkey’s significant military advantage in Idlib gives it the upper hand in negotiations with Russia.\xa0 The Turkish Armed Forces (TSK) have a division-sized contingent (over 20,000 troops) in Idlib. \xa0Turkey also maintains large proxy forces in Idlib, and Salafi-jihadist groups in Idlib would independently resist a regime advance. TSK forces are substantially more capable than their Russian-backed regime opponents; Turkish drone capabilities, for example, have decimated regime forces in limited prior engagements. \xa0Turkey also has a military advantage relative to Russia by virtue of being on the defensive in Idlib, having interior lines in the area, and bordering Syria. Neither Russia nor Turkey likely desires major military confrontation in Idlib. \xa0Russia fears losses to regime units in which it has invested heavily, such as the 25 \xa0Special Tasks Division (aka. Tiger Forces) and the 5 \xa0Corps. Turkish and Turkish-backed forces would also suffer losses, even if at a lower rate, given pro-regime artillery and air capabilities. Turkey would additionally risk losing ground in Idlib and, perhaps more importantly, losing access to Russian concessions it hopes to achieve in negotiations. A deployed Russian conventional unit would thus most likely be intended to compel Turkish concessions in negotiations rather than to participate in combat, although it would be prepared to do so if necessary. Limited and inconclusive but still noteworthy indicators that Russia is preparing for a conventional forces deployment to Syria have been tripped. \xa0Russian Foreign Minister Sergei Lavrov stated on September 21, 2020, “there is no need for the Syrian army and its allies to launch any attack on Idlib. It is only necessary to target terrorist sites and eliminate their only remaining outpost on Syrian territory.” \xa0The apparent dismissal of an offensive operation in the first sentence is offset by the coded language of the second. Lavrov emphasized that Turkey is primarily responsible for the counter-terrorism mission in Idlib and has previously accused Turkey of failing to fulfill its counter-terrorism responsibilities. \xa0Moscow has justified prior pro-regime offensives in Idlib as counter-terrorism operations. “[Practicing] joint operations to localize and resolve armed conflicts related to countering terrorism…in [the] southwest strategic direction” was among the principal stated  ...
#   'keywords': ['idlib',
#    'russia',
#    'russian',
#    'regime',
#    'chemical',
#    'conventional',
#    'turkey',
#    'shughour',
#    'jisr',
#    'forces'],
#   'people': ['Sergei Lavrov'],
#   'places': [{'Lat': 64.6863136, 'Location': 'Russia', 'Lon': 97.7453061},
#    {'Lat': 34.6401861, 'Location': 'Syria', 'Lon': 39.0494106},
#    {'Lat': 38.9597594, 'Location': 'Turkey', 'Lon': 34.9249653},
#    {'Lat': 35.9278306, 'Location': 'Idlib Province', 'Lon': 36.6353017},
#    {'Lat': 55.7504461, 'Location': 'Moscow', 'Lon': 37.6174943},
#    {'Lat': 26.8234472, 'Location': 'Libya', 'Lon': 18.1236723},
#    {'Lat': 35.8600391, 'Location': 'Idlib', 'Lon': 36.5710906},
#    {'Lat': 35.5200185, 'Location': 'Latakia Province', 'Lon': 35.7781044}],
#   'title': 'Russia May Deploy Conventional Forces to Syria',
#   'topic cluster': 38,
#   'url': 'http://www.understandingwar.org/backgrounder/russia-may-deploy-conventional-forces-syria'},
#  {'_id': 1742,
#   'categories': ['OIR Iraq', 'Syrian Conflict', 'Terrorism'],
#   'countries': {'all mentioned countries': ['Syria'], 'focus area': ['Syria']},
#   'date': '2020-10-16T18:24:41-04:00',
#   'full text': 'SDF Begins Mass Release of ISIS Members and Sympathizers in Syria | Institute for the Study of War Search form SDF Begins Mass Release of ISIS Members and Sympathizers in Syria Oct 16, 2020 - Jason Zhou, Eva Kahan By Jason Zhou and Eva Kahan Key Takeaway: The US-backed Syrian Democratic Forces (SDF) has begun large-scale releases of ISIS detainees and internally displaced persons (IDPs), including ISIS sympathizers and the families of ISIS members. The SDF declared a general amnesty for detained criminals and ISIS fighters on October 15 and ISIS sympathizers in the al Hawl IDP camp on October 14. The SDF clarified that the amnesty does not apply to ISIS members found guilty of killing Syrians, an effort to mitigate public backlash. However, the SDF cannot consistently apply that standard, \xa0as it does not have the ability to investigate and prosecute all of its detainees or IDPs. The SDF does not have a process to deradicalize or reintegrate released ISIS sympathizers. The SDF released 631 detainees from Alaya Prison near Qamishli on October 15 and 289 IDPs from al Hawl on October 13. More releases will likely follow in coming days. ISIS will benefit from the injection of new fighters into its insurgency and will likely intimidate and recruit vulnerable civilian returnees. Click here to expand the image. ',
#   'keywords': ['sdf',
#    'sympathizers',
#    'isis',
#    'idps',
#    'detainees',
#    'kahan',
#    'hawl',
#    'eva',
#    'amnesty',
#    'members'],
#   'people': [],
#   'places': [{'Lat': 34.6401861, 'Location': 'Syria', 'Lon': 39.0494106},
#    {'Lat': 37.0402529, 'Location': 'Qamishli', 'Lon': 41.2328836}],
#   'title': 'SDF Begins Mass Release of ISIS Members and Sympathizers in Syria',
#   'topic cluster': 1,
#   'url': 'http://www.understandingwar.org/backgrounder/sdf-begins-mass-release-isis-members-and-sympathizers-syria'},
#  {'_id': 1741,
#   'categories': ['Russia', 'Syrian Conflict', 'Turkey'],
#   'countries': {'all mentioned countries': ['Syria'], 'focus area': ['Syria']},
#   'date': '2020-10-16T16:56:50-04:00',
#   'full text': 'Syria Situation Report: September 30 - October 13, 2020 | Institute for the Study of War Search form Syria Situation Report: September 30 - October 13, 2020 Oct 16, 2020 - Andrew Greco By Andrew Greco and Will Christou (Syria Direct) Key Takeaway: Increasing attacks by Salafi-jihadist groups threaten to destabilize greater Idlib Province and could be exploited by pro-regime actors to conduct a ground offensive. Hay’at Tahrir al-Sham (HTS) and the Syrian National Army (SNA) will likely face increased attacks from Salafi-jihadist groups in greater Idlib Province. HTS and the SNA have seemingly sought to solidify their control of the Syrian opposition by conducting various operations against HaD and\xa0 ISIS from September 30 to October 10. Successive attacks in Aleppo Province and the assassination of two HTS fighters in Idlib Province likely indicate increasing fractures between anti-regime groups. Click here to expand the image. ',
#   'keywords': ['hts',
#    'sna',
#    'greco',
#    'andrew',
#    'idlib',
#    'province',
#    'september',
#    'october',
#    'jihadist',
#    'salafi'],
#   'people': [],
#   'places': [{'Lat': 34.6401861, 'Location': 'Syria', 'Lon': 39.0494106},
#    {'Lat': 35.9278306, 'Location': 'Idlib Province', 'Lon': 36.6353017}],
#   'title': 'Syria Situation Report: September 30 - October 13, 2020',
#   'topic cluster': 38,
#   'url': 'http://www.understandingwar.org/backgrounder/syria-situation-report-september-30-october-13-2020'}]
